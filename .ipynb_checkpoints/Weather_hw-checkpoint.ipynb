# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 637

# %%
#variables to url and units for the API call to openweathermap

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


# set up lists to hold reponse info
w_cities = []
w_countries = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
weather_lat = []
weather_lon = []
dates = []


#initial output message for data retrieval log
print("Beginning Data Retrieval")
print("-"*20)

#variable for number of records - starting value is zero
record = 0


# Loop through the list of cities and perform a request for data on each

for city in cities: 
    #weather_response stores response data from the API call for each city that is passed through
    weather_response = requests.get(url + "appid=" + api_key + "&q=" + city +"&units=" + units).json()
    
    #Exception handling - try to call city name.  
    
    try:
        w_cities.append(weather_response["name"])
    
    #If a key error is returned, print error message and continue with loop
    except KeyError:
        print("City not found....skipping")
        continue
    
    #advance record by 1 after continuing loop
    record = record +1
    
    #output for retrieval log
    print(f"Processing record {record} of Set 1 | {weather_response['name']}")
    
    #populate lists of country variables defined above for each city that is successfully found
    w_countries.append(weather_response["sys"]["country"])
    max_temp.append(weather_response["main"]["temp_max"])
    humidity.append(weather_response["main"]["humidity"])
    cloudiness.append(weather_response["clouds"]["all"])
    wind_speed.append(weather_response["wind"]["speed"])
    weather_lat.append(weather_response["coord"]["lat"])
    weather_lon.append(weather_response["coord"]["lon"])
    dates.append(weather_response["dt"])
# Out:
# Beginning Data Retrieval
# --------------------
# City not found....skipping
# Processing record 1 of Set 1 | Tuktoyaktuk
# Processing record 2 of Set 1 | Murray Bridge
# Processing record 3 of Set 1 | Lasa
# Processing record 4 of Set 1 | Pevek
# Processing record 5 of Set 1 | Tuatapere
# Processing record 6 of Set 1 | Iracoubo
# Processing record 7 of Set 1 | Vaini
# Processing record 8 of Set 1 | Yellowknife
# Processing record 9 of Set 1 | Hadejia
# Processing record 10 of Set 1 | Barrow
# Processing record 11 of Set 1 | Albany
# Processing record 12 of Set 1 | Ushuaia
# Processing record 13 of Set 1 | Taldan
# Processing record 14 of Set 1 | Hermanus
# City not found....skipping
# Processing record 15 of Set 1 | Nuuk
# City not found....skipping
# Processing record 16 of Set 1 | Port Alfred
# Processing record 17 of Set 1 | Salalah
# Processing record 18 of Set 1 | Mykolayiv
# Processing record 19 of Set 1 | Havelock
# Processing record 20 of Set 1 | Kununurra
# Processing record 21 of Set 1 | Jamestown
# City not found....skipping
# Processing record 22 of Set 1 | Abu Samrah
# Processing record 23 of Set 1 | Bethel
# Processing record 24 of Set 1 | Esperance
# City not found....skipping
# Processing record 25 of Set 1 | Monterey
# Processing record 26 of Set 1 | Sao Jose da Coroa Grande
# City not found....skipping
# Processing record 27 of Set 1 | Flin Flon
# Processing record 28 of Set 1 | Lisakovsk
# Processing record 29 of Set 1 | Leningradskiy
# City not found....skipping
# Processing record 30 of Set 1 | Torbay
# Processing record 31 of Set 1 | Kurchum
# Processing record 32 of Set 1 | Nanortalik
# Processing record 33 of Set 1 | Qaanaaq
# Processing record 34 of Set 1 | Ilulissat
# Processing record 35 of Set 1 | Bathsheba
# Processing record 36 of Set 1 | Mataura
# Processing record 37 of Set 1 | Simao
# Processing record 38 of Set 1 | Maniitsoq
# Processing record 39 of Set 1 | Busselton
# City not found....skipping
# Processing record 40 of Set 1 | Avera
# Processing record 41 of Set 1 | Bredasdorp
# Processing record 42 of Set 1 | Rodez
# Processing record 43 of Set 1 | Bela pod Bezdezem
# Processing record 44 of Set 1 | Cidreira
# Processing record 45 of Set 1 | Norman Wells
# Processing record 46 of Set 1 | Punta Arenas
# Processing record 47 of Set 1 | Marovoay
# City not found....skipping
# Processing record 48 of Set 1 | Manoel Urbano
# Processing record 49 of Set 1 | Lushnje
# Processing record 50 of Set 1 | Hambantota
# Processing record 51 of Set 1 | Victoria
# Processing record 52 of Set 1 | Mahebourg
# Processing record 53 of Set 1 | Airai
# Processing record 54 of Set 1 | Cherskiy
# Processing record 55 of Set 1 | Bambous Virieux
# Processing record 56 of Set 1 | Kapaa
# Processing record 57 of Set 1 | Port Elizabeth
# City not found....skipping
# Processing record 58 of Set 1 | Antalaha
# Processing record 59 of Set 1 | Buenos Aires
# Processing record 60 of Set 1 | East London
# Processing record 61 of Set 1 | Lorengau
# Processing record 62 of Set 1 | Vostok
# Processing record 63 of Set 1 | Saint-Philippe
# Processing record 64 of Set 1 | Xining
# Processing record 65 of Set 1 | Katsuura
# Processing record 66 of Set 1 | Margate
# Processing record 67 of Set 1 | Butaritari
# City not found....skipping
# Processing record 68 of Set 1 | Watertown
# Processing record 69 of Set 1 | Castro
# Processing record 70 of Set 1 | Sorland
# Processing record 71 of Set 1 | Marawi
# Processing record 72 of Set 1 | Faya
# City not found....skipping
# Processing record 73 of Set 1 | Voh
# Processing record 74 of Set 1 | Sabya
# Processing record 75 of Set 1 | Zirl
# City not found....skipping
# Processing record 76 of Set 1 | New Norfolk
# Processing record 77 of Set 1 | Middletown
# Processing record 78 of Set 1 | Olhao
# City not found....skipping
# Processing record 79 of Set 1 | Ponta do Sol
# City not found....skipping
# Processing record 80 of Set 1 | Sao Joao da Barra
# Processing record 81 of Set 1 | Chihuahua
# Processing record 82 of Set 1 | Xuddur
# City not found....skipping
# Processing record 83 of Set 1 | Morgan City
# Processing record 84 of Set 1 | Cape Town
# Processing record 85 of Set 1 | Cascais
# Processing record 86 of Set 1 | Lata
# Processing record 87 of Set 1 | Hofn
# City not found....skipping
# Processing record 88 of Set 1 | Bluff
# Processing record 89 of Set 1 | Codrington
# Processing record 90 of Set 1 | Mackenzie
# Processing record 91 of Set 1 | Rikitea
# Processing record 92 of Set 1 | Ancud
# Processing record 93 of Set 1 | Hobart
# Processing record 94 of Set 1 | Molina
# Processing record 95 of Set 1 | Finschhafen
# Processing record 96 of Set 1 | Murgab
# Processing record 97 of Set 1 | Khasan
# Processing record 98 of Set 1 | Alofi
# Processing record 99 of Set 1 | Rawlins
# Processing record 100 of Set 1 | Isoka
# Processing record 101 of Set 1 | Atuona
# Processing record 102 of Set 1 | Hasaki
# Processing record 103 of Set 1 | Kjopsvik
# Processing record 104 of Set 1 | Khatanga
# Processing record 105 of Set 1 | Birao
# Processing record 106 of Set 1 | Cherepet
# Processing record 107 of Set 1 | Ko Samui
# Processing record 108 of Set 1 | Lebu
# City not found....skipping
# Processing record 109 of Set 1 | Puerto Ayora
# Processing record 110 of Set 1 | Saint George
# Processing record 111 of Set 1 | Chanute
# Processing record 112 of Set 1 | Maryville
# City not found....skipping
# City not found....skipping
# Processing record 113 of Set 1 | Biak
# Processing record 114 of Set 1 | Dubbo
# Processing record 115 of Set 1 | Arraial do Cabo
# Processing record 116 of Set 1 | Wilmington
# Processing record 117 of Set 1 | Port Hedland
# Processing record 118 of Set 1 | Bindura
# Processing record 119 of Set 1 | Saint-Leu
# Processing record 120 of Set 1 | Antofagasta
# Processing record 121 of Set 1 | Upernavik
# Processing record 122 of Set 1 | Brae
# Processing record 123 of Set 1 | Uruzgan
# Processing record 124 of Set 1 | Maraa
# Processing record 125 of Set 1 | Luau
# Processing record 126 of Set 1 | Tiznit
# Processing record 127 of Set 1 | Baringo
# Processing record 128 of Set 1 | Quatre Cocos
# Processing record 129 of Set 1 | Victoria
# Processing record 130 of Set 1 | Cedar City
# Processing record 131 of Set 1 | Koumac
# City not found....skipping
# Processing record 132 of Set 1 | Cayenne
# Processing record 133 of Set 1 | Barra Patuca
# Processing record 134 of Set 1 | Severo-Kurilsk
# Processing record 135 of Set 1 | Chuy
# Processing record 136 of Set 1 | Saint Anthony
# Processing record 137 of Set 1 | Clearwater
# City not found....skipping
# Processing record 138 of Set 1 | San Policarpo
# Processing record 139 of Set 1 | Beyneu
# Processing record 140 of Set 1 | Rabo de Peixe
# Processing record 141 of Set 1 | Koulamoutou
# Processing record 142 of Set 1 | Kumluca
# Processing record 143 of Set 1 | Novobiryusinskiy
# Processing record 144 of Set 1 | Ribeira Grande
# Processing record 145 of Set 1 | Sioux Lookout
# Processing record 146 of Set 1 | Celestun
# Processing record 147 of Set 1 | Genhe
# Processing record 148 of Set 1 | Callaway
# Processing record 149 of Set 1 | Saint John
# Processing record 150 of Set 1 | Kangaatsiaq
# Processing record 151 of Set 1 | Nikolskoye
# Processing record 152 of Set 1 | Oktyabrskiy
# Processing record 153 of Set 1 | San Patricio
# Processing record 154 of Set 1 | Lompoc
# Processing record 155 of Set 1 | Port Lincoln
# Processing record 156 of Set 1 | Virginia Beach
# Processing record 157 of Set 1 | Poya
# Processing record 158 of Set 1 | Okha
# Processing record 159 of Set 1 | Chadiza
# Processing record 160 of Set 1 | Atar
# Processing record 161 of Set 1 | Tuy Hoa
# Processing record 162 of Set 1 | Urengoy
# Processing record 163 of Set 1 | Iberia
# Processing record 164 of Set 1 | Mount Gambier
# Processing record 165 of Set 1 | Isangel
# Processing record 166 of Set 1 | Pimentel
# Processing record 167 of Set 1 | Sibu
# Processing record 168 of Set 1 | Xichang
# Processing record 169 of Set 1 | Guarapari
# Processing record 170 of Set 1 | Kiama
# Processing record 171 of Set 1 | Poum
# Processing record 172 of Set 1 | Pyay
# Processing record 173 of Set 1 | Saskylakh
# Processing record 174 of Set 1 | Ebolowa
# Processing record 175 of Set 1 | Khani
# Processing record 176 of Set 1 | Pilar
# Processing record 177 of Set 1 | Hervey Bay
# Processing record 178 of Set 1 | Najran
# Processing record 179 of Set 1 | Kruisfontein
# Processing record 180 of Set 1 | Qaqortoq
# Processing record 181 of Set 1 | Synya
# Processing record 182 of Set 1 | Natchitoches
# Processing record 183 of Set 1 | Melong
# Processing record 184 of Set 1 | Diedorf
# Processing record 185 of Set 1 | Homberg
# Processing record 186 of Set 1 | Great Bend
# Processing record 187 of Set 1 | Hilo
# Processing record 188 of Set 1 | Havre-Saint-Pierre
# Processing record 189 of Set 1 | Saint-Louis
# Processing record 190 of Set 1 | Sao Filipe
# Processing record 191 of Set 1 | Gamboma
# Processing record 192 of Set 1 | Paamiut
# Processing record 193 of Set 1 | Cabo San Lucas
# City not found....skipping
# Processing record 194 of Set 1 | Sivaki
# City not found....skipping
# Processing record 195 of Set 1 | Fairbanks
# Processing record 196 of Set 1 | High Level
# Processing record 197 of Set 1 | Ramshir
# Processing record 198 of Set 1 | Homer
# Processing record 199 of Set 1 | Knysna
# Processing record 200 of Set 1 | Souillac
# Processing record 201 of Set 1 | Chimbote
# City not found....skipping
# Processing record 202 of Set 1 | Los Llanos de Aridane
# Processing record 203 of Set 1 | Cruzeiro do Sul
# Processing record 204 of Set 1 | Chornyanka
# Processing record 205 of Set 1 | Luanda
# Processing record 206 of Set 1 | Vernon
# Processing record 207 of Set 1 | Ibra
# Processing record 208 of Set 1 | Carnarvon
# Processing record 209 of Set 1 | San Andres
# Processing record 210 of Set 1 | Porto Novo
# Processing record 211 of Set 1 | Neuquen
# Processing record 212 of Set 1 | Sri Aman
# Processing record 213 of Set 1 | La Union
# Processing record 214 of Set 1 | Giddarbaha
# Processing record 215 of Set 1 | Rio Grande
# Processing record 216 of Set 1 | Tsumeb
# Processing record 217 of Set 1 | Wucheng
# Processing record 218 of Set 1 | Edirne
# City not found....skipping
# Processing record 219 of Set 1 | Boa Vista
# Processing record 220 of Set 1 | Meulaboh
# Processing record 221 of Set 1 | Kampong Thum
# Processing record 222 of Set 1 | Vila Velha
# Processing record 223 of Set 1 | Kamaishi
# Processing record 224 of Set 1 | Gaillac
# Processing record 225 of Set 1 | Lere
# Processing record 226 of Set 1 | Am Timan
# Processing record 227 of Set 1 | Yerbogachen
# Processing record 228 of Set 1 | Mar del Plata
# Processing record 229 of Set 1 | Kodiak
# Processing record 230 of Set 1 | Shelburne
# Processing record 231 of Set 1 | Kingman
# Processing record 232 of Set 1 | Sun Valley
# Processing record 233 of Set 1 | Campo de Criptana
# Processing record 234 of Set 1 | Kaitangata
# Processing record 235 of Set 1 | Provideniya
# City not found....skipping
# Processing record 236 of Set 1 | Chita
# Processing record 237 of Set 1 | Doha
# Processing record 238 of Set 1 | Deniliquin
# Processing record 239 of Set 1 | Emba
# Processing record 240 of Set 1 | Santa Cruz
# Processing record 241 of Set 1 | Wasilla
# Processing record 242 of Set 1 | Athabasca
# Processing record 243 of Set 1 | Abha
# Processing record 244 of Set 1 | Nyurba
# Processing record 245 of Set 1 | Avarua
# Processing record 246 of Set 1 | Masuguru
# Processing record 247 of Set 1 | Semikarakorsk
# Processing record 248 of Set 1 | Almetyevsk
# Processing record 249 of Set 1 | Ahipara
# Processing record 250 of Set 1 | Hit
# Processing record 251 of Set 1 | Mount Isa
# Processing record 252 of Set 1 | Andros Town
# Processing record 253 of Set 1 | Aden
# Processing record 254 of Set 1 | Vardo
# Processing record 255 of Set 1 | Yendi
# City not found....skipping
# Processing record 256 of Set 1 | Guerrero Negro
# Processing record 257 of Set 1 | Ugoofaaru
# Processing record 258 of Set 1 | Aswan
# Processing record 259 of Set 1 | Svarstad
# Processing record 260 of Set 1 | Timra
# City not found....skipping
# Processing record 261 of Set 1 | Orotukan
# Processing record 262 of Set 1 | Klaksvik
# Processing record 263 of Set 1 | Prieska
# Processing record 264 of Set 1 | Yatou
# Processing record 265 of Set 1 | Sohag
# City not found....skipping
# Processing record 266 of Set 1 | Richards Bay
# Processing record 267 of Set 1 | Coos Bay
# Processing record 268 of Set 1 | Teguise
# City not found....skipping
# Processing record 269 of Set 1 | Abashiri
# Processing record 270 of Set 1 | Aklavik
# Processing record 271 of Set 1 | Namatanai
# Processing record 272 of Set 1 | Dikson
# City not found....skipping
# Processing record 273 of Set 1 | Bogatyye Saby
# City not found....skipping
# Processing record 274 of Set 1 | Saldanha
# Processing record 275 of Set 1 | Matara
# City not found....skipping
# Processing record 276 of Set 1 | Ostrovnoy
# Processing record 277 of Set 1 | Tromso
# Processing record 278 of Set 1 | Nagapattinam
# Processing record 279 of Set 1 | Belmonte
# Processing record 280 of Set 1 | Samarai
# Processing record 281 of Set 1 | Mehamn
# Processing record 282 of Set 1 | Oppdal
# Processing record 283 of Set 1 | Zyryanskoye
# City not found....skipping
# Processing record 284 of Set 1 | Sabzevar
# Processing record 285 of Set 1 | Cockburn Town
# Processing record 286 of Set 1 | San Vicente
# Processing record 287 of Set 1 | Port Macquarie
# Processing record 288 of Set 1 | Pathalgaon
# Processing record 289 of Set 1 | Lumeje
# Processing record 290 of Set 1 | Anloga
# Processing record 291 of Set 1 | Port Augusta
# Processing record 292 of Set 1 | Broome
# Processing record 293 of Set 1 | Hithadhoo
# Processing record 294 of Set 1 | Yar-Sale
# Processing record 295 of Set 1 | Karratha
# Processing record 296 of Set 1 | Price
# Processing record 297 of Set 1 | Kenai
# Processing record 298 of Set 1 | Kingsland
# Processing record 299 of Set 1 | Chapais
# Processing record 300 of Set 1 | Longyearbyen
# Processing record 301 of Set 1 | Petatlan
# Processing record 302 of Set 1 | Aloleng
# Processing record 303 of Set 1 | Minsk
# Processing record 304 of Set 1 | Canutama
# City not found....skipping
# Processing record 305 of Set 1 | Rawson
# Processing record 306 of Set 1 | Kommunisticheskiy
# City not found....skipping
# Processing record 307 of Set 1 | Cacu
# Processing record 308 of Set 1 | Caravelas
# City not found....skipping
# Processing record 309 of Set 1 | Livingstone
# Processing record 310 of Set 1 | Mbamba
# Processing record 311 of Set 1 | Daru
# Processing record 312 of Set 1 | Georgetown
# Processing record 313 of Set 1 | Vanavara
# Processing record 314 of Set 1 | Bagotville
# Processing record 315 of Set 1 | Aleksandrov Gay
# Processing record 316 of Set 1 | Christchurch
# Processing record 317 of Set 1 | Sitka
# Processing record 318 of Set 1 | Faanui
# Processing record 319 of Set 1 | Suileng
# Processing record 320 of Set 1 | Ossora
# Processing record 321 of Set 1 | Boat of Garten
# Processing record 322 of Set 1 | Alegrete
# Processing record 323 of Set 1 | Eggenfelden
# Processing record 324 of Set 1 | Tasiilaq
# Processing record 325 of Set 1 | Dengzhou
# Processing record 326 of Set 1 | Ferme-Neuve
# Processing record 327 of Set 1 | Weligama
# City not found....skipping
# Processing record 328 of Set 1 | Jabinyanah
# Processing record 329 of Set 1 | Portland
# Processing record 330 of Set 1 | Hualmay
# City not found....skipping
# Processing record 331 of Set 1 | Ekhabi
# Processing record 332 of Set 1 | Muisne
# Processing record 333 of Set 1 | Usinsk
# City not found....skipping
# Processing record 334 of Set 1 | Flinders
# Processing record 335 of Set 1 | Cap Malheureux
# Processing record 336 of Set 1 | Touros
# Processing record 337 of Set 1 | Varberg
# Processing record 338 of Set 1 | Segezha
# Processing record 339 of Set 1 | Chauk
# Processing record 340 of Set 1 | Hami
# Processing record 341 of Set 1 | Naze
# Processing record 342 of Set 1 | Tabou
# Processing record 343 of Set 1 | Estrela
# Processing record 344 of Set 1 | Felipe Carrillo Puerto
# Processing record 345 of Set 1 | Malangali
# Processing record 346 of Set 1 | Denpasar
# Processing record 347 of Set 1 | Umm Lajj
# Processing record 348 of Set 1 | Eenhana
# Processing record 349 of Set 1 | Kahului
# Processing record 350 of Set 1 | Gat
# Processing record 351 of Set 1 | Phayao
# Processing record 352 of Set 1 | Kunming
# Processing record 353 of Set 1 | Invermere
# Processing record 354 of Set 1 | Yabassi
# Processing record 355 of Set 1 | Katobu
# Processing record 356 of Set 1 | Fortuna
# Processing record 357 of Set 1 | Komsomolskiy
# Processing record 358 of Set 1 | Sao Paulo de Olivenca
# City not found....skipping
# Processing record 359 of Set 1 | Talnakh
# Processing record 360 of Set 1 | Wewak
# Processing record 361 of Set 1 | Saint-Augustin
# Processing record 362 of Set 1 | Iqaluit
# Processing record 363 of Set 1 | Ilam
# Processing record 364 of Set 1 | Nioro
# Processing record 365 of Set 1 | Kieta
# Processing record 366 of Set 1 | Plettenberg Bay
# Processing record 367 of Set 1 | Ketchikan
# Processing record 368 of Set 1 | Manono
# Processing record 369 of Set 1 | Ballina
# Processing record 370 of Set 1 | Novi Troyany
# City not found....skipping
# Processing record 371 of Set 1 | Port Hardy
# City not found....skipping
# Processing record 372 of Set 1 | Mossendjo
# Processing record 373 of Set 1 | Kaiyuan
# Processing record 374 of Set 1 | Manaure
# Processing record 375 of Set 1 | Narsaq
# Processing record 376 of Set 1 | Altus
# Processing record 377 of Set 1 | Springfield
# Processing record 378 of Set 1 | Maragogi
# Processing record 379 of Set 1 | Noumea
# Processing record 380 of Set 1 | Kodinsk
# Processing record 381 of Set 1 | Grindavik
# Processing record 382 of Set 1 | Naryan-Mar
# Processing record 383 of Set 1 | Kaeo
# Processing record 384 of Set 1 | Nouadhibou
# Processing record 385 of Set 1 | Mushie
# City not found....skipping
# Processing record 386 of Set 1 | Haicheng
# Processing record 387 of Set 1 | Sydney
# Processing record 388 of Set 1 | Vestmannaeyjar
# Processing record 389 of Set 1 | Krasnouralsk
# Processing record 390 of Set 1 | Ranong
# Processing record 391 of Set 1 | Laguna
# City not found....skipping
# Processing record 392 of Set 1 | Whitehorse
# Processing record 393 of Set 1 | Serebryansk
# Processing record 394 of Set 1 | Coquimbo
# Processing record 395 of Set 1 | Turayf
# Processing record 396 of Set 1 | Taoudenni
# Processing record 397 of Set 1 | Hamilton
# Processing record 398 of Set 1 | Kashan
# Processing record 399 of Set 1 | Sechura
# City not found....skipping
# Processing record 400 of Set 1 | Thompson
# Processing record 401 of Set 1 | Bundaberg
# Processing record 402 of Set 1 | Brigantine
# Processing record 403 of Set 1 | Maningrida
# Processing record 404 of Set 1 | Bonthe
# Processing record 405 of Set 1 | Shenjiamen
# Processing record 406 of Set 1 | Zabaykalsk
# Processing record 407 of Set 1 | San Cristobal
# Processing record 408 of Set 1 | Mayo
# Processing record 409 of Set 1 | Picota
# Processing record 410 of Set 1 | Leshukonskoye
# Processing record 411 of Set 1 | Muros
# Processing record 412 of Set 1 | Geraldton
# Processing record 413 of Set 1 | Florence
# Processing record 414 of Set 1 | Bubaque
# Processing record 415 of Set 1 | Pisco
# Processing record 416 of Set 1 | Nemuro
# Processing record 417 of Set 1 | La Sierra
# Processing record 418 of Set 1 | Khor
# Processing record 419 of Set 1 | Lahad Datu
# Processing record 420 of Set 1 | Te Anau
# Processing record 421 of Set 1 | Hearst
# City not found....skipping
# Processing record 422 of Set 1 | Cosmesti
# Processing record 423 of Set 1 | Puerto Baquerizo Moreno
# City not found....skipping
# City not found....skipping
# Processing record 424 of Set 1 | Toul
# Processing record 425 of Set 1 | San Pedro
# Processing record 426 of Set 1 | Terney
# Processing record 427 of Set 1 | Port Keats
# Processing record 428 of Set 1 | Itoman
# Processing record 429 of Set 1 | Eyl
# Processing record 430 of Set 1 | Marshfield
# Processing record 431 of Set 1 | Necochea
# Processing record 432 of Set 1 | Grenada
# Processing record 433 of Set 1 | Byron Bay
# Processing record 434 of Set 1 | Maumere
# Processing record 435 of Set 1 | Yulara
# City not found....skipping
# Processing record 436 of Set 1 | Aurora
# Processing record 437 of Set 1 | Barcelos
# Processing record 438 of Set 1 | Piacabucu
# Processing record 439 of Set 1 | Dunedin
# Processing record 440 of Set 1 | Bonavista
# Processing record 441 of Set 1 | Utiel
# Processing record 442 of Set 1 | Svetlogorsk
# Processing record 443 of Set 1 | Napasar
# City not found....skipping
# Processing record 444 of Set 1 | Cupertino
# Processing record 445 of Set 1 | Talara
# Processing record 446 of Set 1 | Kudahuvadhoo
# Processing record 447 of Set 1 | Dzhebariki-Khaya
# Processing record 448 of Set 1 | Patiya
# City not found....skipping
# Processing record 449 of Set 1 | Koumra
# Processing record 450 of Set 1 | Husavik
# Processing record 451 of Set 1 | Guaramirim
# Processing record 452 of Set 1 | Lamar
# Processing record 453 of Set 1 | Sergeyevka
# Processing record 454 of Set 1 | Warrnambool
# Processing record 455 of Set 1 | Walvis Bay
# Processing record 456 of Set 1 | Ramona
# Processing record 457 of Set 1 | Aguada de Pasajeros
# Processing record 458 of Set 1 | Revda
# Processing record 459 of Set 1 | Manado
# Processing record 460 of Set 1 | Julio de Castilhos
# Processing record 461 of Set 1 | Slave Lake
# Processing record 462 of Set 1 | Sokolo
# Processing record 463 of Set 1 | Lavrentiya
# City not found....skipping
# Processing record 464 of Set 1 | Serowe
# Processing record 465 of Set 1 | Kita
# Processing record 466 of Set 1 | Healesville
# Processing record 467 of Set 1 | Grenaa
# City not found....skipping
# Processing record 468 of Set 1 | Ahmadpur East
# Processing record 469 of Set 1 | Petropavlovsk-Kamchatskiy
# Processing record 470 of Set 1 | Huainan
# Processing record 471 of Set 1 | Kardailovo
# Processing record 472 of Set 1 | Ipixuna
# Processing record 473 of Set 1 | Srednekolymsk
# Processing record 474 of Set 1 | Tabat
# Processing record 475 of Set 1 | Palmer
# Processing record 476 of Set 1 | Lagoa
# Processing record 477 of Set 1 | Chokurdakh
# Processing record 478 of Set 1 | Harbin
# Processing record 479 of Set 1 | Karpogory
# City not found....skipping
# Processing record 480 of Set 1 | Lazaro Cardenas
# Processing record 481 of Set 1 | Sobolevo
# Processing record 482 of Set 1 | Villa Bisono
# Processing record 483 of Set 1 | Sarkand
# Processing record 484 of Set 1 | Tiksi
# Processing record 485 of Set 1 | Oyama
# Processing record 486 of Set 1 | Warrington
# Processing record 487 of Set 1 | Berdigestyakh
# Processing record 488 of Set 1 | Jalu
# Processing record 489 of Set 1 | Inhambane
# Processing record 490 of Set 1 | Port-Gentil
# Processing record 491 of Set 1 | Areosa
# Processing record 492 of Set 1 | Forestville
# Processing record 493 of Set 1 | Manokwari
# Processing record 494 of Set 1 | Pulandian
# Processing record 495 of Set 1 | Groa
# Processing record 496 of Set 1 | Warmbad
# Processing record 497 of Set 1 | Saint-Joseph
# Processing record 498 of Set 1 | Impfondo
# Processing record 499 of Set 1 | Alyangula
# Processing record 500 of Set 1 | Dayong
# Processing record 501 of Set 1 | Paraiso
# Processing record 502 of Set 1 | Amahai
# Processing record 503 of Set 1 | Uttarkashi
# Processing record 504 of Set 1 | Alta Floresta
# Processing record 505 of Set 1 | Marzuq
# Processing record 506 of Set 1 | Kavieng
# Processing record 507 of Set 1 | Pemba
# Processing record 508 of Set 1 | Abnub
# City not found....skipping
# Processing record 509 of Set 1 | Rudnogorsk
# Processing record 510 of Set 1 | Somerset
# Processing record 511 of Set 1 | Gloucester
# Processing record 512 of Set 1 | Luderitz
# Processing record 513 of Set 1 | Sesheke
# Processing record 514 of Set 1 | Carroll
# City not found....skipping
# Processing record 515 of Set 1 | Playa del Carmen
# Processing record 516 of Set 1 | Alice Springs
# Processing record 517 of Set 1 | Marsa Matruh
# City not found....skipping
# Processing record 518 of Set 1 | Taiyuan
# City not found....skipping
# Processing record 519 of Set 1 | Marrakesh
# Processing record 520 of Set 1 | Otacilio Costa
# Processing record 521 of Set 1 | Baghdad
# Processing record 522 of Set 1 | Pithiviers
# City not found....skipping
# Processing record 523 of Set 1 | Bull Savanna
# Processing record 524 of Set 1 | Selma
# Processing record 525 of Set 1 | Waipawa
# Processing record 526 of Set 1 | Bandar-e Anzali
# Processing record 527 of Set 1 | Susanville
# City not found....skipping
# Processing record 528 of Set 1 | Hasanabad
# Processing record 529 of Set 1 | Shache
# Processing record 530 of Set 1 | Conde
# Processing record 531 of Set 1 | Sadove
# Processing record 532 of Set 1 | Touho
# Processing record 533 of Set 1 | Springbok
# Processing record 534 of Set 1 | Dakar
# Processing record 535 of Set 1 | Tucurui
# Processing record 536 of Set 1 | Vila do Maio
# Processing record 537 of Set 1 | Along
# Processing record 538 of Set 1 | Prince Rupert
# Processing record 539 of Set 1 | Constantine
# Processing record 540 of Set 1 | Flagstaff
# City not found....skipping
# Processing record 541 of Set 1 | Les Cayes
# City not found....skipping
# Processing record 542 of Set 1 | Estelle
# Processing record 543 of Set 1 | Egvekinot
# Processing record 544 of Set 1 | Henties Bay
# Processing record 545 of Set 1 | Sola
# Processing record 546 of Set 1 | El Calvario
# Processing record 547 of Set 1 | Hovd
# Processing record 548 of Set 1 | Agadez
# City not found....skipping
# Processing record 549 of Set 1 | Gwadar
# Processing record 550 of Set 1 | Swan Hill
# City not found....skipping
# Processing record 551 of Set 1 | Broken Hill
# Processing record 552 of Set 1 | Ilebo
# Processing record 553 of Set 1 | Palana
# City not found....skipping
# Processing record 554 of Set 1 | Timmins
# City not found....skipping
# Processing record 555 of Set 1 | Fez
# Processing record 556 of Set 1 | Oshkosh
# City not found....skipping
# Processing record 557 of Set 1 | Garbolovo
# Processing record 558 of Set 1 | Kulevcha
# Processing record 559 of Set 1 | Krasni Okny
# Processing record 560 of Set 1 | Skegness
# Processing record 561 of Set 1 | Constitucion
# City not found....skipping
# Processing record 562 of Set 1 | Sawakin
# Processing record 563 of Set 1 | Luebo
# Processing record 564 of Set 1 | Dezful
# Processing record 565 of Set 1 | General Pico
# Processing record 566 of Set 1 | Gatesville
# Processing record 567 of Set 1 | Magistralnyy

# %%
#dataframe for weather data for each city

#format dates from UNIX time more readable year-month-day

#empty list for date objects
date_objects=[]

#for loop to format dates from UNIX time
for date in dates:
    formatted_date=datetime.utcfromtimestamp(date).strftime('%Y-%m-%d')
    date_objects.append(formatted_date)
    
#create city weather database
city_weather_raw_df = pd.DataFrame({"City":w_cities,
                                "Cloudiness":cloudiness,
                                "Country":w_countries,
                                "Date":date_objects,
                                "Humidity":humidity,
                                "Lat":weather_lat,
                                "Lon":weather_lon,
                                "Max_Temp":max_temp,
                                "Wind Speed":wind_speed
})

city_weather_df = city_weather_raw_df.drop(city_weather_raw_df[city_weather_raw_df.Humidity > 100].index)

#output csv file
city_weather_df.to_csv("output.csv")

#show data frame
city_weather_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0    Tuktoyaktuk          90      CA  2018-12-22        84  69.44 -133.03
# 1  Murray Bridge           0      AU  2018-12-22       100 -35.12  139.28
# 2           Lasa          40      CY  2018-12-22        82  34.92   32.53
# 3          Pevek          48      RU  2018-12-22       100  69.70  170.27
# 4      Tuatapere           0      NZ  2018-12-22       100 -46.13  167.69
#
#    Max_Temp  Wind Speed
# 0     -0.41        3.36
# 1     54.70        7.63
# 2     60.80        4.70
# 3    -22.12        2.71
# 4     44.04        6.40

# %%
#Latitude vs. Temperature Plot

plt.scatter(city_weather_df["Lat"], city_weather_df["Max_Temp"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#take first entry in date list for title of chart
title_date = city_weather_df["Date"].iloc[0]

plt.title(F"City Latitude vs. Max Temperature ({title_date})")
plt.show()

# %%
#Latitude vs. Humidity

plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Humidity ({title_date})")
plt.show()

# %%
#Latitude vs. Cloudiness

plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Cloudiness ({title_date})")
plt.show()

# %%
#Latitude vs. Windspeed

plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Wind Speed ({title_date})")
plt.show()
