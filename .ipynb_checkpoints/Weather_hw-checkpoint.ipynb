# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
#variables to url and units for the API call to openweathermap

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up lists to hold reponse info
w_cities = []
w_countries = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
weather_lat = []
weather_lon = []
dates = []


#initial output message for data retrieval log
print("Beginning Data Retrieval")
print("-"*20)

#variable for number of records and sets - starting value is zero
Record = 0
Set = 0

# Loop through the list of cities and perform a request for data on each
for city in cities: 
    
    #weather_response stores response data from the API call for each city that is passed through
    weather_response = requests.get(url + "appid=" + api_key + "&q=" + city +"&units=" + units).json()
    
    #Exception handling - try to call city name.  
    
    try:
        w_cities.append(weather_response["name"])
    
    #If a key error is returned, print error message and continue with loop
    
    except KeyError:
        print("City not found....skipping")
        continue
    
    #advance record by 1 after continuing loop
    Record = Record +1
    
    if Record % 50 == 1:
        Set = Set + 1
        Record = 1
    
    #output for retrieval log
    print(f"Processing Record {Record} of Set {Set} | {weather_response['name']}")
    
    #populate lists of country variables defined above for each city that is successfully found
    w_countries.append(weather_response["sys"]["country"])
    max_temp.append(weather_response["main"]["temp_max"])
    humidity.append(weather_response["main"]["humidity"])
    cloudiness.append(weather_response["clouds"]["all"])
    wind_speed.append(weather_response["wind"]["speed"])
    weather_lat.append(weather_response["coord"]["lat"])
    weather_lon.append(weather_response["coord"]["lon"])
    dates.append(weather_response["dt"])

print('-'*20)
print("Data Retrieval Complete")
print('-'*20)
# Out:
# Beginning Data Retrieval
# --------------------
# Processing Record 1 of Set 1 | New Norfolk
# Processing Record 2 of Set 1 | Rikitea
# Processing Record 3 of Set 1 | Sohag
# Processing Record 4 of Set 1 | Ribeira Grande
# City not found....skipping
# Processing Record 5 of Set 1 | Yellowknife
# Processing Record 6 of Set 1 | Qaanaaq
# Processing Record 7 of Set 1 | Gberia Fotombu
# Processing Record 8 of Set 1 | Mataura
# Processing Record 9 of Set 1 | Saint-Philippe
# Processing Record 10 of Set 1 | Khatanga
# Processing Record 11 of Set 1 | Sarai Mir
# Processing Record 12 of Set 1 | Atuona
# Processing Record 13 of Set 1 | Lagos de Moreno
# Processing Record 14 of Set 1 | Ikovka
# Processing Record 15 of Set 1 | Yerbogachen
# Processing Record 16 of Set 1 | Aklavik
# Processing Record 17 of Set 1 | Karratha
# Processing Record 18 of Set 1 | Isangel
# City not found....skipping
# Processing Record 19 of Set 1 | Chuy
# Processing Record 20 of Set 1 | Jennings
# Processing Record 21 of Set 1 | Hervey Bay
# Processing Record 22 of Set 1 | Norman Wells
# Processing Record 23 of Set 1 | East London
# Processing Record 24 of Set 1 | Broken Hill
# Processing Record 25 of Set 1 | Tasiilaq
# City not found....skipping
# Processing Record 26 of Set 1 | Snezhnogorsk
# City not found....skipping
# Processing Record 27 of Set 1 | Nikolskoye
# Processing Record 28 of Set 1 | Sao Joao da Barra
# Processing Record 29 of Set 1 | Hilo
# Processing Record 30 of Set 1 | Vanimo
# Processing Record 31 of Set 1 | Puerto Ayora
# Processing Record 32 of Set 1 | Avarua
# Processing Record 33 of Set 1 | Hobart
# Processing Record 34 of Set 1 | Visnes
# Processing Record 35 of Set 1 | Bredasdorp
# Processing Record 36 of Set 1 | Castro
# Processing Record 37 of Set 1 | Cape Town
# Processing Record 38 of Set 1 | Ushuaia
# Processing Record 39 of Set 1 | Lindas
# City not found....skipping
# Processing Record 40 of Set 1 | Rawson
# Processing Record 41 of Set 1 | Albany
# Processing Record 42 of Set 1 | Kalmar
# Processing Record 43 of Set 1 | Port Alfred
# Processing Record 44 of Set 1 | Taoudenni
# Processing Record 45 of Set 1 | Kapaa
# Processing Record 46 of Set 1 | Victoria
# Processing Record 47 of Set 1 | Vaini
# Processing Record 48 of Set 1 | Miri
# City not found....skipping
# Processing Record 49 of Set 1 | Zambezi
# Processing Record 50 of Set 1 | Nanortalik
# Processing Record 1 of Set 2 | Bambous Virieux
# Processing Record 2 of Set 2 | Bara
# Processing Record 3 of Set 2 | Archidona
# Processing Record 4 of Set 2 | Teya
# Processing Record 5 of Set 2 | San Patricio
# City not found....skipping
# Processing Record 6 of Set 2 | Takoradi
# Processing Record 7 of Set 2 | Talmenka
# Processing Record 8 of Set 2 | Thompson
# Processing Record 9 of Set 2 | Bethel
# Processing Record 10 of Set 2 | Avera
# City not found....skipping
# Processing Record 11 of Set 2 | Jalu
# Processing Record 12 of Set 2 | Caravelas
# Processing Record 13 of Set 2 | Pevek
# Processing Record 14 of Set 2 | Pangai
# Processing Record 15 of Set 2 | Cherskiy
# Processing Record 16 of Set 2 | Chokurdakh
# Processing Record 17 of Set 2 | Polovinnoye
# Processing Record 18 of Set 2 | Mount Isa
# Processing Record 19 of Set 2 | Saint-Augustin
# Processing Record 20 of Set 2 | Sitka
# Processing Record 21 of Set 2 | Muzhi
# Processing Record 22 of Set 2 | Tuskegee
# Processing Record 23 of Set 2 | Tuy Hoa
# Processing Record 24 of Set 2 | Vao
# Processing Record 25 of Set 2 | Saint George
# Processing Record 26 of Set 2 | Olinda
# Processing Record 27 of Set 2 | Coquimbo
# Processing Record 28 of Set 2 | Port Blair
# Processing Record 29 of Set 2 | Iqaluit
# Processing Record 30 of Set 2 | Poum
# City not found....skipping
# Processing Record 31 of Set 2 | Geraldton
# Processing Record 32 of Set 2 | Lorengau
# Processing Record 33 of Set 2 | Katsuura
# Processing Record 34 of Set 2 | Saskylakh
# Processing Record 35 of Set 2 | Dikson
# Processing Record 36 of Set 2 | Jijiga
# Processing Record 37 of Set 2 | Kodiak
# Processing Record 38 of Set 2 | Busselton
# Processing Record 39 of Set 2 | Bluff
# Processing Record 40 of Set 2 | Acari
# Processing Record 41 of Set 2 | Peru
# City not found....skipping
# Processing Record 42 of Set 2 | Ponta do Sol
# Processing Record 43 of Set 2 | Pocosol
# Processing Record 44 of Set 2 | Pacific Grove
# Processing Record 45 of Set 2 | Hambantota
# Processing Record 46 of Set 2 | Los Llanos de Aridane
# Processing Record 47 of Set 2 | Tatarskaya Kargala
# Processing Record 48 of Set 2 | Emba
# Processing Record 49 of Set 2 | Port Moresby
# Processing Record 50 of Set 2 | Port Elizabeth
# Processing Record 1 of Set 3 | Lagoa
# Processing Record 2 of Set 3 | Broome
# Processing Record 3 of Set 3 | Ballina
# Processing Record 4 of Set 3 | Cabo San Lucas
# Processing Record 5 of Set 3 | Cairns
# Processing Record 6 of Set 3 | Jamestown
# Processing Record 7 of Set 3 | Nelson Bay
# Processing Record 8 of Set 3 | Warrington
# Processing Record 9 of Set 3 | Upernavik
# Processing Record 10 of Set 3 | Komsomolskiy
# Processing Record 11 of Set 3 | Pochutla
# Processing Record 12 of Set 3 | Smithers
# Processing Record 13 of Set 3 | Bokaro
# Processing Record 14 of Set 3 | Monrovia
# Processing Record 15 of Set 3 | Palembang
# Processing Record 16 of Set 3 | Bathsheba
# Processing Record 17 of Set 3 | Carroll
# Processing Record 18 of Set 3 | Westport
# Processing Record 19 of Set 3 | Egvekinot
# City not found....skipping
# Processing Record 20 of Set 3 | Constitucion
# Processing Record 21 of Set 3 | Arraial do Cabo
# Processing Record 22 of Set 3 | Grand-Lahou
# Processing Record 23 of Set 3 | San Cristobal
# Processing Record 24 of Set 3 | Airai
# Processing Record 25 of Set 3 | Provideniya
# Processing Record 26 of Set 3 | Barrow
# City not found....skipping
# Processing Record 27 of Set 3 | Butembo
# Processing Record 28 of Set 3 | Byron Bay
# Processing Record 29 of Set 3 | Pontes e Lacerda
# Processing Record 30 of Set 3 | Tiksi
# Processing Record 31 of Set 3 | Bressuire
# Processing Record 32 of Set 3 | Luderitz
# Processing Record 33 of Set 3 | Mana
# Processing Record 34 of Set 3 | Poltavka
# Processing Record 35 of Set 3 | Eureka
# City not found....skipping
# Processing Record 36 of Set 3 | Fairbanks
# City not found....skipping
# City not found....skipping
# Processing Record 37 of Set 3 | Waipawa
# City not found....skipping
# Processing Record 38 of Set 3 | Cap Malheureux
# Processing Record 39 of Set 3 | Punta Arenas
# Processing Record 40 of Set 3 | Lebu
# Processing Record 41 of Set 3 | San Carlos de Bariloche
# City not found....skipping
# Processing Record 42 of Set 3 | Caxias
# Processing Record 43 of Set 3 | Krasnyy Chikoy
# Processing Record 44 of Set 3 | Margate
# Processing Record 45 of Set 3 | Kortkeros
# Processing Record 46 of Set 3 | Butaritari
# Processing Record 47 of Set 3 | Clyde River
# Processing Record 48 of Set 3 | San Ramon
# Processing Record 49 of Set 3 | Bud
# Processing Record 50 of Set 3 | Hami
# Processing Record 1 of Set 4 | Ancud
# Processing Record 2 of Set 4 | Fortuna
# Processing Record 3 of Set 4 | Hermanus
# Processing Record 4 of Set 4 | Mackenzie
# Processing Record 5 of Set 4 | Tambovka
# Processing Record 6 of Set 4 | Luanda
# Processing Record 7 of Set 4 | Blagoyevo
# Processing Record 8 of Set 4 | Sobral
# Processing Record 9 of Set 4 | Talnakh
# Processing Record 10 of Set 4 | Kavaratti
# Processing Record 11 of Set 4 | Lusambo
# Processing Record 12 of Set 4 | Mount Gambier
# Processing Record 13 of Set 4 | Fort Nelson
# City not found....skipping
# Processing Record 14 of Set 4 | Plavsk
# Processing Record 15 of Set 4 | Biak
# Processing Record 16 of Set 4 | Tilichiki
# Processing Record 17 of Set 4 | Namibe
# Processing Record 18 of Set 4 | Iskateley
# Processing Record 19 of Set 4 | Shimoda
# Processing Record 20 of Set 4 | Villa Carlos Paz
# Processing Record 21 of Set 4 | Krasnaya Gora
# Processing Record 22 of Set 4 | Agadez
# Processing Record 23 of Set 4 | Vila
# Processing Record 24 of Set 4 | Whyalla
# Processing Record 25 of Set 4 | Yekaterinoslavka
# Processing Record 26 of Set 4 | Bouna
# Processing Record 27 of Set 4 | Berlevag
# Processing Record 28 of Set 4 | Plettenberg Bay
# Processing Record 29 of Set 4 | Awjilah
# City not found....skipping
# Processing Record 30 of Set 4 | Bonthe
# Processing Record 31 of Set 4 | Simbahan
# Processing Record 32 of Set 4 | Olga
# Processing Record 33 of Set 4 | Kuchinarai
# Processing Record 34 of Set 4 | Kahului
# City not found....skipping
# Processing Record 35 of Set 4 | Zhigansk
# Processing Record 36 of Set 4 | Demir Hisar
# City not found....skipping
# Processing Record 37 of Set 4 | Georgetown
# Processing Record 38 of Set 4 | Tuktoyaktuk
# Processing Record 39 of Set 4 | Baracoa
# Processing Record 40 of Set 4 | Mahebourg
# Processing Record 41 of Set 4 | Honggang
# Processing Record 42 of Set 4 | Kaohsiung
# Processing Record 43 of Set 4 | Nyahururu
# Processing Record 44 of Set 4 | Uyar
# Processing Record 45 of Set 4 | Salalah
# Processing Record 46 of Set 4 | Kaele
# Processing Record 47 of Set 4 | Itarema
# Processing Record 48 of Set 4 | Vila do Maio
# Processing Record 49 of Set 4 | Narsaq
# Processing Record 50 of Set 4 | Saint-Paul
# Processing Record 1 of Set 5 | Maldonado
# Processing Record 2 of Set 5 | Taksimo
# Processing Record 3 of Set 5 | Isiro
# Processing Record 4 of Set 5 | Tabriz
# Processing Record 5 of Set 5 | Khandyga
# City not found....skipping
# Processing Record 6 of Set 5 | Agirish
# Processing Record 7 of Set 5 | Jishu
# City not found....skipping
# Processing Record 8 of Set 5 | Grants
# Processing Record 9 of Set 5 | Ranong
# City not found....skipping
# Processing Record 10 of Set 5 | Dzerzhinskoye
# Processing Record 11 of Set 5 | Iskilip
# City not found....skipping
# Processing Record 12 of Set 5 | Nuevo Ideal
# Processing Record 13 of Set 5 | Tamasane
# Processing Record 14 of Set 5 | Maragogi
# Processing Record 15 of Set 5 | Zhezkazgan
# Processing Record 16 of Set 5 | Pauini
# Processing Record 17 of Set 5 | Ryde
# Processing Record 18 of Set 5 | Jahazpur
# City not found....skipping
# Processing Record 19 of Set 5 | Picos
# Processing Record 20 of Set 5 | Churapcha
# Processing Record 21 of Set 5 | Tauranga
# Processing Record 22 of Set 5 | Cidreira
# Processing Record 23 of Set 5 | Hasaki
# Processing Record 24 of Set 5 | Naze
# Processing Record 25 of Set 5 | Mae Sot
# Processing Record 26 of Set 5 | Souillac
# Processing Record 27 of Set 5 | Severo-Kurilsk
# Processing Record 28 of Set 5 | Dudinka
# Processing Record 29 of Set 5 | Tezu
# Processing Record 30 of Set 5 | Pruhonice
# Processing Record 31 of Set 5 | Deputatskiy
# Processing Record 32 of Set 5 | Labytnangi
# Processing Record 33 of Set 5 | Leningradskiy
# Processing Record 34 of Set 5 | General Pico
# Processing Record 35 of Set 5 | Grindavik
# Processing Record 36 of Set 5 | Touros
# Processing Record 37 of Set 5 | Hithadhoo
# City not found....skipping
# Processing Record 38 of Set 5 | Eufaula
# Processing Record 39 of Set 5 | Fengxian
# City not found....skipping
# Processing Record 40 of Set 5 | Palmer
# Processing Record 41 of Set 5 | Uruacu
# Processing Record 42 of Set 5 | Rocky Mountain House
# Processing Record 43 of Set 5 | Kavieng
# Processing Record 44 of Set 5 | Valleyview
# City not found....skipping
# Processing Record 45 of Set 5 | Mabaruma
# Processing Record 46 of Set 5 | Sarahan
# Processing Record 47 of Set 5 | Rock Springs
# Processing Record 48 of Set 5 | Halifax
# Processing Record 49 of Set 5 | Ostrovnoy
# Processing Record 50 of Set 5 | Pangnirtung
# Processing Record 1 of Set 6 | Bandarbeyla
# Processing Record 2 of Set 6 | Angatuba
# Processing Record 3 of Set 6 | Alcala la Real
# Processing Record 4 of Set 6 | Texarkana
# City not found....skipping
# Processing Record 5 of Set 6 | Namanga
# Processing Record 6 of Set 6 | Davlekanovo
# Processing Record 7 of Set 6 | Qaqortoq
# Processing Record 8 of Set 6 | Rincon
# Processing Record 9 of Set 6 | Mecca
# Processing Record 10 of Set 6 | Mangrol
# Processing Record 11 of Set 6 | Uturoa
# Processing Record 12 of Set 6 | Hobyo
# Processing Record 13 of Set 6 | Pentecoste
# Processing Record 14 of Set 6 | Tirumullaivasal
# Processing Record 15 of Set 6 | Rumoi
# Processing Record 16 of Set 6 | Alghero
# City not found....skipping
# Processing Record 17 of Set 6 | Bangolo
# Processing Record 18 of Set 6 | Inongo
# Processing Record 19 of Set 6 | Mongar
# City not found....skipping
# Processing Record 20 of Set 6 | Toltestava
# Processing Record 21 of Set 6 | Mar del Plata
# Processing Record 22 of Set 6 | Makasar
# Processing Record 23 of Set 6 | Tautira
# Processing Record 24 of Set 6 | Lucenec
# Processing Record 25 of Set 6 | Namatanai
# City not found....skipping
# Processing Record 26 of Set 6 | Dolores
# Processing Record 27 of Set 6 | Garowe
# Processing Record 28 of Set 6 | Akureyri
# Processing Record 29 of Set 6 | Guozhen
# Processing Record 30 of Set 6 | Sorland
# City not found....skipping
# Processing Record 31 of Set 6 | Zonguldak
# Processing Record 32 of Set 6 | Sukhobezvodnoye
# Processing Record 33 of Set 6 | Saldanha
# City not found....skipping
# Processing Record 34 of Set 6 | Ambon
# Processing Record 35 of Set 6 | Okha
# Processing Record 36 of Set 6 | Laureles
# Processing Record 37 of Set 6 | Kaitangata
# Processing Record 38 of Set 6 | Jutai
# Processing Record 39 of Set 6 | Nishihara
# Processing Record 40 of Set 6 | Vrede
# Processing Record 41 of Set 6 | Alofi
# Processing Record 42 of Set 6 | Umm Bab
# Processing Record 43 of Set 6 | Conde
# Processing Record 44 of Set 6 | Lhokseumawe
# Processing Record 45 of Set 6 | Yangjiang
# City not found....skipping
# Processing Record 46 of Set 6 | Nador
# Processing Record 47 of Set 6 | Petropavlovsk-Kamchatskiy
# Processing Record 48 of Set 6 | Vila Velha
# Processing Record 49 of Set 6 | Bulawayo
# Processing Record 50 of Set 6 | Bin Qirdan
# Processing Record 1 of Set 7 | Puerto Palomas
# Processing Record 2 of Set 7 | Virginia Beach
# Processing Record 3 of Set 7 | Tutoia
# City not found....skipping
# Processing Record 4 of Set 7 | Cayenne
# Processing Record 5 of Set 7 | Piacabucu
# Processing Record 6 of Set 7 | Puerto Leguizamo
# Processing Record 7 of Set 7 | Codrington
# Processing Record 8 of Set 7 | Foumban
# Processing Record 9 of Set 7 | Aswan
# Processing Record 10 of Set 7 | Craig
# Processing Record 11 of Set 7 | Shache
# Processing Record 12 of Set 7 | Koumac
# Processing Record 13 of Set 7 | Bereda
# Processing Record 14 of Set 7 | Marquard
# City not found....skipping
# City not found....skipping
# Processing Record 15 of Set 7 | Hamilton
# Processing Record 16 of Set 7 | Malpe
# Processing Record 17 of Set 7 | Lata
# Processing Record 18 of Set 7 | Lake Havasu City
# Processing Record 19 of Set 7 | Torredonjimeno
# Processing Record 20 of Set 7 | Gat
# Processing Record 21 of Set 7 | Arak
# City not found....skipping
# Processing Record 22 of Set 7 | Timizart
# Processing Record 23 of Set 7 | Chapais
# Processing Record 24 of Set 7 | Celestun
# Processing Record 25 of Set 7 | Sayyan
# Processing Record 26 of Set 7 | Cheney
# Processing Record 27 of Set 7 | Dogondoutchi
# Processing Record 28 of Set 7 | Makurdi
# Processing Record 29 of Set 7 | Mount Pleasant
# Processing Record 30 of Set 7 | Alekseyevsk
# Processing Record 31 of Set 7 | Lensk
# Processing Record 32 of Set 7 | Anori
# City not found....skipping
# Processing Record 33 of Set 7 | Grand-Santi
# Processing Record 34 of Set 7 | Honiara
# Processing Record 35 of Set 7 | Binalan
# Processing Record 36 of Set 7 | Vestmanna
# Processing Record 37 of Set 7 | Mezen
# Processing Record 38 of Set 7 | Pisco
# Processing Record 39 of Set 7 | Shimanovsk
# City not found....skipping
# Processing Record 40 of Set 7 | Sidi Ali
# Processing Record 41 of Set 7 | Guerrero Negro
# Processing Record 42 of Set 7 | Quatre Cocos
# Processing Record 43 of Set 7 | Esperance
# City not found....skipping
# Processing Record 44 of Set 7 | Toora-Khem
# Processing Record 45 of Set 7 | Yulara
# Processing Record 46 of Set 7 | Inirida
# Processing Record 47 of Set 7 | Portree
# Processing Record 48 of Set 7 | Evensk
# Processing Record 49 of Set 7 | Torbay
# Processing Record 50 of Set 7 | Simpang
# City not found....skipping
# Processing Record 1 of Set 8 | Carnarvon
# Processing Record 2 of Set 8 | Kazlu Ruda
# City not found....skipping
# Processing Record 3 of Set 8 | Sabya
# Processing Record 4 of Set 8 | College
# Processing Record 5 of Set 8 | Kargil
# Processing Record 6 of Set 8 | Plotnikovo
# Processing Record 7 of Set 8 | Ardesen
# Processing Record 8 of Set 8 | Tuatapere
# Processing Record 9 of Set 8 | San Quintin
# Processing Record 10 of Set 8 | Calama
# Processing Record 11 of Set 8 | Valdivia
# Processing Record 12 of Set 8 | Faya
# Processing Record 13 of Set 8 | Sioux Lookout
# Processing Record 14 of Set 8 | Prince George
# Processing Record 15 of Set 8 | Sampit
# Processing Record 16 of Set 8 | Port Macquarie
# Processing Record 17 of Set 8 | Kolyvan
# Processing Record 18 of Set 8 | Zhanakorgan
# Processing Record 19 of Set 8 | Aykhal
# Processing Record 20 of Set 8 | Anloga
# Processing Record 21 of Set 8 | Gladstone
# Processing Record 22 of Set 8 | Hirara
# Processing Record 23 of Set 8 | Alenquer
# Processing Record 24 of Set 8 | Nemuro
# Processing Record 25 of Set 8 | Keetmanshoop
# City not found....skipping
# Processing Record 26 of Set 8 | Beringovskiy
# Processing Record 27 of Set 8 | Fremont
# Processing Record 28 of Set 8 | Santa Cruz
# Processing Record 29 of Set 8 | Bonavista
# Processing Record 30 of Set 8 | Ulaangom
# Processing Record 31 of Set 8 | Turukhansk
# Processing Record 32 of Set 8 | El Salto
# City not found....skipping
# Processing Record 33 of Set 8 | Manokwari
# Processing Record 34 of Set 8 | Tungor
# Processing Record 35 of Set 8 | Sur
# Processing Record 36 of Set 8 | Miramar
# Processing Record 37 of Set 8 | Praia da Vitoria
# Processing Record 38 of Set 8 | Boyolangu
# Processing Record 39 of Set 8 | Dandong
# City not found....skipping
# Processing Record 40 of Set 8 | Te Anau
# Processing Record 41 of Set 8 | Belyy Yar
# Processing Record 42 of Set 8 | Vanavara
# Processing Record 43 of Set 8 | Pangoa
# Processing Record 44 of Set 8 | Balikpapan
# City not found....skipping
# Processing Record 45 of Set 8 | Verkhnyaya Toyma
# City not found....skipping
# Processing Record 46 of Set 8 | Kula
# Processing Record 47 of Set 8 | Kozyatyn
# Processing Record 48 of Set 8 | Lockhart
# Processing Record 49 of Set 8 | Bridlington
# Processing Record 50 of Set 8 | Vardo
# Processing Record 1 of Set 9 | Sobolevo
# Processing Record 2 of Set 9 | Vila Franca do Campo
# City not found....skipping
# Processing Record 3 of Set 9 | Corn Island
# Processing Record 4 of Set 9 | Huilong
# Processing Record 5 of Set 9 | Baherden
# Processing Record 6 of Set 9 | Faanui
# Processing Record 7 of Set 9 | Manggar
# Processing Record 8 of Set 9 | Flinders
# Processing Record 9 of Set 9 | Merta
# Processing Record 10 of Set 9 | Rapid Valley
# Processing Record 11 of Set 9 | Gizo
# Processing Record 12 of Set 9 | Nantucket
# Processing Record 13 of Set 9 | Rognan
# Processing Record 14 of Set 9 | Kirakira
# Processing Record 15 of Set 9 | Anadyr
# Processing Record 16 of Set 9 | Wang Saphung
# Processing Record 17 of Set 9 | Antofagasta
# City not found....skipping
# Processing Record 18 of Set 9 | Ringe
# Processing Record 19 of Set 9 | Gisborne
# City not found....skipping
# Processing Record 20 of Set 9 | Batagay-Alyta
# Processing Record 21 of Set 9 | Meulaboh
# Processing Record 22 of Set 9 | Eregli
# Processing Record 23 of Set 9 | Adilcevaz
# Processing Record 24 of Set 9 | Barahona
# Processing Record 25 of Set 9 | Zhanaozen
# Processing Record 26 of Set 9 | Myingyan
# Processing Record 27 of Set 9 | Fort Saint James
# Processing Record 28 of Set 9 | Paka
# Processing Record 29 of Set 9 | Sao Filipe
# Processing Record 30 of Set 9 | Luang Prabang
# Processing Record 31 of Set 9 | Kahta
# Processing Record 32 of Set 9 | Bom Jesus da Lapa
# Processing Record 33 of Set 9 | Kralendijk
# Processing Record 34 of Set 9 | Tomatlan
# Processing Record 35 of Set 9 | Yar-Sale
# Processing Record 36 of Set 9 | Portland
# City not found....skipping
# Processing Record 37 of Set 9 | San Ignacio
# Processing Record 38 of Set 9 | Tongchuan
# Processing Record 39 of Set 9 | Sabang
# Processing Record 40 of Set 9 | Mbengwi
# Processing Record 41 of Set 9 | Surt
# Processing Record 42 of Set 9 | Guaraniacu
# Processing Record 43 of Set 9 | Ixtapa
# Processing Record 44 of Set 9 | Cerritos
# Processing Record 45 of Set 9 | Kajaani
# Processing Record 46 of Set 9 | Coralville
# Processing Record 47 of Set 9 | Digha
# Processing Record 48 of Set 9 | Ilulissat
# Processing Record 49 of Set 9 | Meadow Lake
# Processing Record 50 of Set 9 | Zharkent
# Processing Record 1 of Set 10 | Shingu
# Processing Record 2 of Set 10 | Mitsamiouli
# Processing Record 3 of Set 10 | Ugoofaaru
# Processing Record 4 of Set 10 | Coihaique
# Processing Record 5 of Set 10 | Talcahuano
# Processing Record 6 of Set 10 | Tagusao
# Processing Record 7 of Set 10 | Haines Junction
# Processing Record 8 of Set 10 | Hargeysa
# Processing Record 9 of Set 10 | Manadhoo
# Processing Record 10 of Set 10 | Beni Suef
# Processing Record 11 of Set 10 | Chicama
# Processing Record 12 of Set 10 | Port Hardy
# Processing Record 13 of Set 10 | Kloulklubed
# Processing Record 14 of Set 10 | Jatai
# Processing Record 15 of Set 10 | Tumpat
# Processing Record 16 of Set 10 | Kudahuvadhoo
# Processing Record 17 of Set 10 | Partizansk
# Processing Record 18 of Set 10 | Moose Factory
# Processing Record 19 of Set 10 | Manakara
# Processing Record 20 of Set 10 | Gatehouse of Fleet
# Processing Record 21 of Set 10 | Santa
# Processing Record 22 of Set 10 | Vina del Mar
# Processing Record 23 of Set 10 | Liverpool
# Processing Record 24 of Set 10 | Adrar
# Processing Record 25 of Set 10 | Ambilobe
# Processing Record 26 of Set 10 | Mulege
# Processing Record 27 of Set 10 | Vysokogornyy
# Processing Record 28 of Set 10 | Mashhad
# Processing Record 29 of Set 10 | Mattru
# Processing Record 30 of Set 10 | Husavik
# Processing Record 31 of Set 10 | Griffith
# Processing Record 32 of Set 10 | Tura
# Processing Record 33 of Set 10 | Alyangula
# Processing Record 34 of Set 10 | Kolyshley
# Processing Record 35 of Set 10 | Carmen
# Processing Record 36 of Set 10 | Karatu
# Processing Record 37 of Set 10 | Turka
# Processing Record 38 of Set 10 | Vestmannaeyjar
# Processing Record 39 of Set 10 | Quthing
# Processing Record 40 of Set 10 | Ilo
# Processing Record 41 of Set 10 | Sechura
# Processing Record 42 of Set 10 | Polunochnoye
# Processing Record 43 of Set 10 | Cockburn Town
# Processing Record 44 of Set 10 | Jumla
# Processing Record 45 of Set 10 | Muravlenko
# Processing Record 46 of Set 10 | Havelock
# Processing Record 47 of Set 10 | Chake Chake
# City not found....skipping
# Processing Record 48 of Set 10 | Gazojak
# Processing Record 49 of Set 10 | Nizhniy Odes
# Processing Record 50 of Set 10 | Kondopoga
# Processing Record 1 of Set 11 | Abong Mbang
# Processing Record 2 of Set 11 | Port Hedland
# Processing Record 3 of Set 11 | San Policarpo
# Processing Record 4 of Set 11 | Biltine
# Processing Record 5 of Set 11 | Zverinogolovskoye
# Processing Record 6 of Set 11 | Zaranj
# Processing Record 7 of Set 11 | Tupik
# Processing Record 8 of Set 11 | Bambanglipuro
# Processing Record 9 of Set 11 | Kendari
# Processing Record 10 of Set 11 | Thinadhoo
# Processing Record 11 of Set 11 | Phrae
# Processing Record 12 of Set 11 | Nobres
# Processing Record 13 of Set 11 | Buala
# Processing Record 14 of Set 11 | Tarbagatay
# Processing Record 15 of Set 11 | Joao Pinheiro
# Processing Record 16 of Set 11 | Yeppoon
# Processing Record 17 of Set 11 | Madimba
# Processing Record 18 of Set 11 | Little Current
# Processing Record 19 of Set 11 | Hushitai
# Processing Record 20 of Set 11 | Kenai
# Processing Record 21 of Set 11 | Brae
# Processing Record 22 of Set 11 | Kumluca
# Processing Record 23 of Set 11 | Vadso
# Processing Record 24 of Set 11 | Nuuk
# Processing Record 25 of Set 11 | Altamont
# Processing Record 26 of Set 11 | Cotonou
# Processing Record 27 of Set 11 | Bayir
# Processing Record 28 of Set 11 | Sassandra
# City not found....skipping
# Processing Record 29 of Set 11 | Samfya
# Processing Record 30 of Set 11 | Fomboni
# Processing Record 31 of Set 11 | Yamada
# Processing Record 32 of Set 11 | Kruisfontein
# Processing Record 33 of Set 11 | Milledgeville
# Processing Record 34 of Set 11 | Hailin
# City not found....skipping
# Processing Record 35 of Set 11 | Sibolga
# Processing Record 36 of Set 11 | Baykit
# City not found....skipping
# Processing Record 37 of Set 11 | Howard Springs
# Processing Record 38 of Set 11 | Mackay
# Processing Record 39 of Set 11 | Grants Pass
# Processing Record 40 of Set 11 | Maceio
# Processing Record 41 of Set 11 | Porangatu
# Processing Record 42 of Set 11 | Mandalgovi
# Processing Record 43 of Set 11 | Sandwick
# Processing Record 44 of Set 11 | Itacare
# Processing Record 45 of Set 11 | Tecoanapa
# Processing Record 46 of Set 11 | Marrakesh
# City not found....skipping
# Processing Record 47 of Set 11 | Koygorodok
# Processing Record 48 of Set 11 | Xingyi
# City not found....skipping
# City not found....skipping
# Processing Record 49 of Set 11 | Samarai
# Processing Record 50 of Set 11 | Harper
# Processing Record 1 of Set 12 | Urucui
# City not found....skipping
# Processing Record 2 of Set 12 | Bacabal
# Processing Record 3 of Set 12 | Yinchuan
# Processing Record 4 of Set 12 | Nome
# Processing Record 5 of Set 12 | Burnie
# Processing Record 6 of Set 12 | Opuwo
# Processing Record 7 of Set 12 | Longyearbyen
# Processing Record 8 of Set 12 | Paamiut
# Processing Record 9 of Set 12 | Hammerfest
# Processing Record 10 of Set 12 | Awbari
# Processing Record 11 of Set 12 | Terekli-Mekteb
# City not found....skipping
# Processing Record 12 of Set 12 | Uusikaupunki
# Processing Record 13 of Set 12 | Lompoc
# Processing Record 14 of Set 12 | Beloha
# Processing Record 15 of Set 12 | Mumbwa
# Processing Record 16 of Set 12 | Tigzirt
# --------------------
# Data Retrieval Complete
# --------------------

# %%
#dataframe for weather data for each city

#empty list for date objects
date_objects=[]

#for loop to format dates from UNIX time
for date in dates:
    formatted_date=datetime.utcfromtimestamp(date).strftime('%Y-%m-%d')
    date_objects.append(formatted_date)
    
#create city weather database
city_weather_raw_df = pd.DataFrame({"City":w_cities,
                                "Cloudiness":cloudiness,
                                "Country":w_countries,
                                "Date":date_objects,
                                "Humidity":humidity,
                                "Lat":weather_lat,
                                "Lon":weather_lon,
                                "Max_Temp":max_temp,
                                "Wind Speed":wind_speed
})

#drop entries where Humidity is reported as >100% and put into new dataframe
city_weather_df = city_weather_raw_df.drop(city_weather_raw_df[city_weather_raw_df.Humidity > 100].index)

#output csv file
city_weather_df.to_csv("output.csv")

#show data frame
city_weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0     New Norfolk          40      AU  2018-12-24        67 -42.78  147.06
# 1         Rikitea           0      PF  2018-12-24        99 -23.12 -134.97
# 2           Sohag           0      EG  2018-12-24        58  26.55   31.70
# 3  Ribeira Grande          20      PT  2018-12-24        66  38.52  -28.70
# 4     Yellowknife          75      CA  2018-12-24        75  62.45 -114.38
#
#    Max_Temp  Wind Speed
# 0     60.80       11.41
# 1     78.78       15.23
# 2     57.20        8.05
# 3     51.80        3.36
# 4    -14.81        4.70

# %%
#Latitude vs. Temperature Plot

plt.scatter(city_weather_df["Lat"], city_weather_df["Max_Temp"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#take first entry in date list for title of chart
title_date = city_weather_df["Date"].iloc[0]

plt.title(F"City Latitude vs. Max Temperature ({title_date})")
plt.savefig("Latitude_vs_Temp.png")
plt.show()

# %%
#Latitude vs. Humidity

plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Humidity ({title_date})")
plt.savefig("Latitude_vs_Humidity.png")
plt.show()

# %%
#Latitude vs. Cloudiness

plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Cloudiness ({title_date})")
plt.savefig("Latitude_vs_Cloudiness.png")
plt.show()

# %%
#Latitude vs. Windspeed

plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Wind Speed ({title_date})")
plt.savefig("Latitude_vs_WindSpeed.png")
plt.show()
