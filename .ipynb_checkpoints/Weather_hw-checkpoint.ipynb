# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
#variables to url and units for the API call to openweathermap

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up lists to hold reponse info
w_cities = []
w_countries = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
weather_lat = []
weather_lon = []
dates = []


#initial output message for data retrieval log
print("Beginning Data Retrieval")
print("-"*20)

#variable for number of records and sets - starting value is zero
Record = 0
Set = 0

# Loop through the list of cities and perform a request for data on each
for city in cities: 
    
    #weather_response stores response data from the API call for each city that is passed through
    weather_response = requests.get(url + "appid=" + api_key + "&q=" + city +"&units=" + units).json()
    
    #Exception handling - try to call city name.  
    
    try:
        w_cities.append(weather_response["name"])
    
    #If a key error is returned, print error message and continue with loop
    
    except KeyError:
        print("City not found....skipping")
        continue
    
    #advance record by 1 after continuing loop
    Record = Record +1
    
    #advance Set by 1 when each set of 50 is complete.  Reset Record back to 1
    if Record % 50 == 1:
        Set = Set + 1
        Record = 1
    
    #output for retrieval log
    print(f"Processing Record {Record} of Set {Set} | {weather_response['name']}")
    
    #populate lists of country variables defined above for each city that is successfully found
    w_countries.append(weather_response["sys"]["country"])
    max_temp.append(weather_response["main"]["temp_max"])
    humidity.append(weather_response["main"]["humidity"])
    cloudiness.append(weather_response["clouds"]["all"])
    wind_speed.append(weather_response["wind"]["speed"])
    weather_lat.append(weather_response["coord"]["lat"])
    weather_lon.append(weather_response["coord"]["lon"])
    dates.append(weather_response["dt"])

print('-'*20)
print("Data Retrieval Complete")
print('-'*20)
# Out:
# Beginning Data Retrieval
# --------------------
# Processing Record 1 of Set 1 | Saurimo
# City not found....skipping
# Processing Record 2 of Set 1 | Beihai
# Processing Record 3 of Set 1 | Vaini
# Processing Record 4 of Set 1 | Saint-Augustin
# Processing Record 5 of Set 1 | Honningsvag
# Processing Record 6 of Set 1 | Bambous Virieux
# Processing Record 7 of Set 1 | Teguise
# City not found....skipping
# Processing Record 8 of Set 1 | Castro
# Processing Record 9 of Set 1 | Zhezkazgan
# Processing Record 10 of Set 1 | Carnarvon
# Processing Record 11 of Set 1 | Mataura
# Processing Record 12 of Set 1 | Cape Town
# Processing Record 13 of Set 1 | Nanortalik
# Processing Record 14 of Set 1 | Mahebourg
# Processing Record 15 of Set 1 | Yellowknife
# Processing Record 16 of Set 1 | Kaitangata
# City not found....skipping
# Processing Record 17 of Set 1 | Sitka
# Processing Record 18 of Set 1 | Hithadhoo
# Processing Record 19 of Set 1 | Chokurdakh
# Processing Record 20 of Set 1 | Braganca
# Processing Record 21 of Set 1 | Porto Novo
# Processing Record 22 of Set 1 | Lethem
# Processing Record 23 of Set 1 | Rikitea
# Processing Record 24 of Set 1 | Busselton
# Processing Record 25 of Set 1 | Constitucion
# Processing Record 26 of Set 1 | Beringovskiy
# Processing Record 27 of Set 1 | Itoman
# Processing Record 28 of Set 1 | Grand Forks
# Processing Record 29 of Set 1 | Norman Wells
# Processing Record 30 of Set 1 | Cabo San Lucas
# Processing Record 31 of Set 1 | Tuktoyaktuk
# Processing Record 32 of Set 1 | Launceston
# Processing Record 33 of Set 1 | Dunedin
# City not found....skipping
# Processing Record 34 of Set 1 | Qaanaaq
# Processing Record 35 of Set 1 | Castelnau-le-Lez
# Processing Record 36 of Set 1 | Kavieng
# Processing Record 37 of Set 1 | Luganville
# Processing Record 38 of Set 1 | Hobart
# Processing Record 39 of Set 1 | Wentzville
# Processing Record 40 of Set 1 | Dikson
# Processing Record 41 of Set 1 | Atuona
# Processing Record 42 of Set 1 | Ixtapa
# Processing Record 43 of Set 1 | Provideniya
# City not found....skipping
# Processing Record 44 of Set 1 | Saint-Philippe
# Processing Record 45 of Set 1 | Ponta do Sol
# Processing Record 46 of Set 1 | Voh
# Processing Record 47 of Set 1 | Port Macquarie
# Processing Record 48 of Set 1 | Jamestown
# Processing Record 49 of Set 1 | Bonthe
# Processing Record 50 of Set 1 | Platanos
# Processing Record 1 of Set 2 | Chuy
# Processing Record 2 of Set 2 | Rawson
# Processing Record 3 of Set 2 | Ancud
# Processing Record 4 of Set 2 | Salalah
# Processing Record 5 of Set 2 | La Reforma
# Processing Record 6 of Set 2 | Roros
# Processing Record 7 of Set 2 | Punta Arenas
# Processing Record 8 of Set 2 | Severo-Kurilsk
# Processing Record 9 of Set 2 | Coari
# Processing Record 10 of Set 2 | Svetlogorsk
# Processing Record 11 of Set 2 | Barrow
# Processing Record 12 of Set 2 | Cidreira
# Processing Record 13 of Set 2 | Kapaa
# City not found....skipping
# Processing Record 14 of Set 2 | Lebu
# City not found....skipping
# Processing Record 15 of Set 2 | Margate
# Processing Record 16 of Set 2 | Thompson
# Processing Record 17 of Set 2 | Petropavlovsk-Kamchatskiy
# Processing Record 18 of Set 2 | Pevek
# Processing Record 19 of Set 2 | Avarua
# Processing Record 20 of Set 2 | Ouadda
# Processing Record 21 of Set 2 | Hokitika
# Processing Record 22 of Set 2 | Albany
# Processing Record 23 of Set 2 | Ostrovnoy
# Processing Record 24 of Set 2 | Kalianget
# Processing Record 25 of Set 2 | Altamont
# Processing Record 26 of Set 2 | San Policarpo
# Processing Record 27 of Set 2 | Pedernales
# Processing Record 28 of Set 2 | Usinsk
# City not found....skipping
# Processing Record 29 of Set 2 | Bintulu
# Processing Record 30 of Set 2 | Ulaanbaatar
# Processing Record 31 of Set 2 | Breves
# Processing Record 32 of Set 2 | Poronaysk
# Processing Record 33 of Set 2 | Lima
# Processing Record 34 of Set 2 | Quatre Cocos
# City not found....skipping
# Processing Record 35 of Set 2 | Borogontsy
# Processing Record 36 of Set 2 | Montemorelos
# Processing Record 37 of Set 2 | Ukiah
# City not found....skipping
# Processing Record 38 of Set 2 | Bluff
# Processing Record 39 of Set 2 | Shimoda
# City not found....skipping
# Processing Record 40 of Set 2 | Hasaki
# Processing Record 41 of Set 2 | Saint George
# Processing Record 42 of Set 2 | Balabac
# Processing Record 43 of Set 2 | Gamba
# Processing Record 44 of Set 2 | Nizhnevartovsk
# Processing Record 45 of Set 2 | Tabou
# Processing Record 46 of Set 2 | Port Alfred
# Processing Record 47 of Set 2 | Bonavista
# Processing Record 48 of Set 2 | Roebourne
# Processing Record 49 of Set 2 | Bathsheba
# Processing Record 50 of Set 2 | Puerto Ayora
# City not found....skipping
# Processing Record 1 of Set 3 | Plettenberg Bay
# Processing Record 2 of Set 3 | Ushuaia
# Processing Record 3 of Set 3 | Alofi
# Processing Record 4 of Set 3 | Bandarbeyla
# Processing Record 5 of Set 3 | Houma
# Processing Record 6 of Set 3 | Palmer
# Processing Record 7 of Set 3 | Hermanus
# City not found....skipping
# Processing Record 8 of Set 3 | Cururupu
# Processing Record 9 of Set 3 | Yumen
# Processing Record 10 of Set 3 | Rorvik
# Processing Record 11 of Set 3 | Goderich
# Processing Record 12 of Set 3 | Airai
# Processing Record 13 of Set 3 | Yala
# Processing Record 14 of Set 3 | Port Elizabeth
# Processing Record 15 of Set 3 | Tasiilaq
# Processing Record 16 of Set 3 | Fortuna
# Processing Record 17 of Set 3 | Topolobampo
# Processing Record 18 of Set 3 | Faanui
# Processing Record 19 of Set 3 | Aras
# Processing Record 20 of Set 3 | Pringsewu
# Processing Record 21 of Set 3 | Bilibino
# Processing Record 22 of Set 3 | Guaranda
# Processing Record 23 of Set 3 | Matipo
# Processing Record 24 of Set 3 | Zunyi
# Processing Record 25 of Set 3 | Nouadhibou
# Processing Record 26 of Set 3 | Guerrero Negro
# City not found....skipping
# Processing Record 27 of Set 3 | Bredasdorp
# Processing Record 28 of Set 3 | Hengshan
# Processing Record 29 of Set 3 | Georgetown
# Processing Record 30 of Set 3 | Buchanan
# Processing Record 31 of Set 3 | Codrington
# Processing Record 32 of Set 3 | Port Hedland
# Processing Record 33 of Set 3 | New Norfolk
# Processing Record 34 of Set 3 | Hilo
# Processing Record 35 of Set 3 | Puerto Baquerizo Moreno
# Processing Record 36 of Set 3 | Ust-Tsilma
# Processing Record 37 of Set 3 | Narsaq
# Processing Record 38 of Set 3 | Pontianak
# City not found....skipping
# Processing Record 39 of Set 3 | Port-Gentil
# Processing Record 40 of Set 3 | Twin Falls
# Processing Record 41 of Set 3 | Cooma
# Processing Record 42 of Set 3 | Kamenka
# Processing Record 43 of Set 3 | Lincoln
# Processing Record 44 of Set 3 | Lorengau
# Processing Record 45 of Set 3 | Vestmannaeyjar
# City not found....skipping
# Processing Record 46 of Set 3 | Bafia
# Processing Record 47 of Set 3 | Shingu
# Processing Record 48 of Set 3 | Satao
# Processing Record 49 of Set 3 | Klaksvik
# Processing Record 50 of Set 3 | Fairbanks
# City not found....skipping
# Processing Record 1 of Set 4 | Haines Junction
# Processing Record 2 of Set 4 | Shizunai
# Processing Record 3 of Set 4 | Sierra Vista
# Processing Record 4 of Set 4 | Luderitz
# Processing Record 5 of Set 4 | Salo
# Processing Record 6 of Set 4 | Grand Gaube
# Processing Record 7 of Set 4 | Kilindoni
# Processing Record 8 of Set 4 | Si Bun Ruang
# City not found....skipping
# Processing Record 9 of Set 4 | Kodiak
# Processing Record 10 of Set 4 | Saldanha
# Processing Record 11 of Set 4 | Arraial do Cabo
# Processing Record 12 of Set 4 | Itupiranga
# Processing Record 13 of Set 4 | Grindavik
# Processing Record 14 of Set 4 | Buala
# Processing Record 15 of Set 4 | East London
# Processing Record 16 of Set 4 | Kimbe
# City not found....skipping
# Processing Record 17 of Set 4 | Mahanoro
# Processing Record 18 of Set 4 | Longyearbyen
# Processing Record 19 of Set 4 | Mar del Plata
# Processing Record 20 of Set 4 | Talnakh
# Processing Record 21 of Set 4 | Half Moon Bay
# Processing Record 22 of Set 4 | Nome
# City not found....skipping
# Processing Record 23 of Set 4 | Victoria
# Processing Record 24 of Set 4 | San Cristobal
# Processing Record 25 of Set 4 | Lagoa
# Processing Record 26 of Set 4 | Cayenne
# Processing Record 27 of Set 4 | Cherskiy
# Processing Record 28 of Set 4 | Isangel
# Processing Record 29 of Set 4 | Kalulushi
# Processing Record 30 of Set 4 | Upernavik
# City not found....skipping
# Processing Record 31 of Set 4 | Kokopo
# Processing Record 32 of Set 4 | Santa Isabel do Rio Negro
# Processing Record 33 of Set 4 | Dedougou
# Processing Record 34 of Set 4 | Cavalcante
# Processing Record 35 of Set 4 | Wanning
# Processing Record 36 of Set 4 | Riyadh
# Processing Record 37 of Set 4 | Qaqortoq
# Processing Record 38 of Set 4 | Dakar
# Processing Record 39 of Set 4 | Esperance
# Processing Record 40 of Set 4 | Kamphaeng Phet
# City not found....skipping
# Processing Record 41 of Set 4 | Rabo de Peixe
# Processing Record 42 of Set 4 | Saskylakh
# Processing Record 43 of Set 4 | Kidodi
# Processing Record 44 of Set 4 | Paamiut
# Processing Record 45 of Set 4 | Laramie
# City not found....skipping
# Processing Record 46 of Set 4 | Banjar
# Processing Record 47 of Set 4 | Marsaxlokk
# Processing Record 48 of Set 4 | Black River
# City not found....skipping
# Processing Record 49 of Set 4 | Ippy
# Processing Record 50 of Set 4 | Tiksi
# Processing Record 1 of Set 5 | Yaan
# Processing Record 2 of Set 5 | Port Blair
# Processing Record 3 of Set 5 | Napier
# Processing Record 4 of Set 5 | Nikolskoye
# Processing Record 5 of Set 5 | Mount Gambier
# Processing Record 6 of Set 5 | Ormara
# Processing Record 7 of Set 5 | Mayo
# Processing Record 8 of Set 5 | Hamilton
# Processing Record 9 of Set 5 | Chicama
# Processing Record 10 of Set 5 | Qasigiannguit
# Processing Record 11 of Set 5 | Warren
# Processing Record 12 of Set 5 | Kodinsk
# Processing Record 13 of Set 5 | Freeport
# Processing Record 14 of Set 5 | Ylivieska
# Processing Record 15 of Set 5 | Markova
# Processing Record 16 of Set 5 | Butaritari
# Processing Record 17 of Set 5 | Necochea
# Processing Record 18 of Set 5 | San Juan
# Processing Record 19 of Set 5 | Ust-Ishim
# Processing Record 20 of Set 5 | Batagay-Alyta
# Processing Record 21 of Set 5 | Torbay
# City not found....skipping
# Processing Record 22 of Set 5 | Uray
# Processing Record 23 of Set 5 | Tarquinia
# Processing Record 24 of Set 5 | Moron
# Processing Record 25 of Set 5 | Kununurra
# Processing Record 26 of Set 5 | Proletarskiy
# Processing Record 27 of Set 5 | Christchurch
# City not found....skipping
# Processing Record 28 of Set 5 | Panguna
# Processing Record 29 of Set 5 | Senador Jose Porfirio
# Processing Record 30 of Set 5 | Alice Springs
# Processing Record 31 of Set 5 | Cermik
# Processing Record 32 of Set 5 | La Ligua
# Processing Record 33 of Set 5 | Zapolyarnyy
# City not found....skipping
# Processing Record 34 of Set 5 | Zhoucheng
# Processing Record 35 of Set 5 | Tiarei
# Processing Record 36 of Set 5 | Kargasok
# Processing Record 37 of Set 5 | Waingapu
# Processing Record 38 of Set 5 | Coahuayana
# Processing Record 39 of Set 5 | Trelew
# Processing Record 40 of Set 5 | Gornoye Loo
# Processing Record 41 of Set 5 | Oktyabrskiy
# Processing Record 42 of Set 5 | Beni
# Processing Record 43 of Set 5 | Misawa
# Processing Record 44 of Set 5 | Joshimath
# Processing Record 45 of Set 5 | Padang
# Processing Record 46 of Set 5 | Teknaf
# City not found....skipping
# City not found....skipping
# City not found....skipping
# Processing Record 47 of Set 5 | Khatanga
# City not found....skipping
# Processing Record 48 of Set 5 | Havelock
# City not found....skipping
# City not found....skipping
# Processing Record 49 of Set 5 | Francisco Sa
# Processing Record 50 of Set 5 | Maningrida
# Processing Record 1 of Set 6 | Katsuura
# Processing Record 2 of Set 6 | Coquimbo
# City not found....skipping
# Processing Record 3 of Set 6 | Ribeira Grande
# Processing Record 4 of Set 6 | Rafai
# Processing Record 5 of Set 6 | Placido de Castro
# Processing Record 6 of Set 6 | Yeppoon
# City not found....skipping
# Processing Record 7 of Set 6 | Tuatapere
# Processing Record 8 of Set 6 | La Primavera
# Processing Record 9 of Set 6 | Merrill
# Processing Record 10 of Set 6 | Axim
# Processing Record 11 of Set 6 | Samut Songkhram
# Processing Record 12 of Set 6 | Cabedelo
# Processing Record 13 of Set 6 | Manavalakurichi
# Processing Record 14 of Set 6 | Pangnirtung
# Processing Record 15 of Set 6 | Champerico
# Processing Record 16 of Set 6 | Tezu
# Processing Record 17 of Set 6 | Raudeberg
# Processing Record 18 of Set 6 | San Patricio
# Processing Record 19 of Set 6 | Biograd na Moru
# Processing Record 20 of Set 6 | Manta
# Processing Record 21 of Set 6 | Dubbo
# Processing Record 22 of Set 6 | Sao Filipe
# Processing Record 23 of Set 6 | Estelle
# Processing Record 24 of Set 6 | Zhangye
# Processing Record 25 of Set 6 | Pitkyaranta
# Processing Record 26 of Set 6 | Lebanon
# Processing Record 27 of Set 6 | Piracaia
# Processing Record 28 of Set 6 | Portland
# Processing Record 29 of Set 6 | Bethel
# Processing Record 30 of Set 6 | San Luis
# City not found....skipping
# Processing Record 31 of Set 6 | Aklavik
# Processing Record 32 of Set 6 | Barra
# Processing Record 33 of Set 6 | Petukhovo
# Processing Record 34 of Set 6 | Cedar Rapids
# City not found....skipping
# Processing Record 35 of Set 6 | Bafoulabe
# Processing Record 36 of Set 6 | Abu Samrah
# Processing Record 37 of Set 6 | Clyde River
# Processing Record 38 of Set 6 | Poum
# Processing Record 39 of Set 6 | Richards Bay
# City not found....skipping
# City not found....skipping
# Processing Record 40 of Set 6 | Yurla
# City not found....skipping
# Processing Record 41 of Set 6 | Villa de San Antonio
# Processing Record 42 of Set 6 | Poya
# Processing Record 43 of Set 6 | Acapulco
# Processing Record 44 of Set 6 | Pinhao
# Processing Record 45 of Set 6 | Geraldton
# Processing Record 46 of Set 6 | Omboue
# Processing Record 47 of Set 6 | Sibolga
# Processing Record 48 of Set 6 | Cikupa
# Processing Record 49 of Set 6 | Kamina
# Processing Record 50 of Set 6 | Husavik
# Processing Record 1 of Set 7 | Nsanje
# Processing Record 2 of Set 7 | Kahului
# Processing Record 3 of Set 7 | Ipil
# Processing Record 4 of Set 7 | Rock Springs
# Processing Record 5 of Set 7 | Kutum
# Processing Record 6 of Set 7 | Pidhorodne
# Processing Record 7 of Set 7 | Laguna
# Processing Record 8 of Set 7 | Wencheng
# Processing Record 9 of Set 7 | Camacha
# City not found....skipping
# Processing Record 10 of Set 7 | Mackay
# Processing Record 11 of Set 7 | Pisco
# Processing Record 12 of Set 7 | General Pico
# City not found....skipping
# Processing Record 13 of Set 7 | Ahipara
# Processing Record 14 of Set 7 | Phan Thiet
# Processing Record 15 of Set 7 | Khawhai
# Processing Record 16 of Set 7 | Korsor
# Processing Record 17 of Set 7 | Whitehaven
# Processing Record 18 of Set 7 | Karlskrona
# Processing Record 19 of Set 7 | Pampa
# Processing Record 20 of Set 7 | Jilib
# Processing Record 21 of Set 7 | Sambava
# Processing Record 22 of Set 7 | North Ogden
# Processing Record 23 of Set 7 | Miyako
# Processing Record 24 of Set 7 | Eyl
# City not found....skipping
# Processing Record 25 of Set 7 | Homer
# Processing Record 26 of Set 7 | Qixingtai
# Processing Record 27 of Set 7 | Bela
# Processing Record 28 of Set 7 | Fukuma
# Processing Record 29 of Set 7 | Goundi
# Processing Record 30 of Set 7 | Mitu
# Processing Record 31 of Set 7 | Taitung
# Processing Record 32 of Set 7 | Macheng
# Processing Record 33 of Set 7 | Paijan
# City not found....skipping
# Processing Record 34 of Set 7 | Wucheng
# Processing Record 35 of Set 7 | Lagunas
# Processing Record 36 of Set 7 | Ayagoz
# Processing Record 37 of Set 7 | Zhovkva
# Processing Record 38 of Set 7 | Lasa
# City not found....skipping
# Processing Record 39 of Set 7 | Razole
# Processing Record 40 of Set 7 | Nova Olimpia
# Processing Record 41 of Set 7 | Grand-Santi
# Processing Record 42 of Set 7 | Teya
# Processing Record 43 of Set 7 | Lompoc
# Processing Record 44 of Set 7 | Shelburne
# Processing Record 45 of Set 7 | Egvekinot
# Processing Record 46 of Set 7 | Vardo
# City not found....skipping
# Processing Record 47 of Set 7 | Springbok
# Processing Record 48 of Set 7 | Aden
# Processing Record 49 of Set 7 | Kiunga
# Processing Record 50 of Set 7 | Vila Franca do Campo
# Processing Record 1 of Set 8 | Ketchikan
# City not found....skipping
# Processing Record 2 of Set 8 | Loanda
# Processing Record 3 of Set 8 | Sibi
# Processing Record 4 of Set 8 | Oktyabrskoye
# Processing Record 5 of Set 8 | Belyy Yar
# Processing Record 6 of Set 8 | Chara
# Processing Record 7 of Set 8 | Kodino
# City not found....skipping
# Processing Record 8 of Set 8 | Puerto Leguizamo
# Processing Record 9 of Set 8 | Hofn
# Processing Record 10 of Set 8 | Islamkot
# Processing Record 11 of Set 8 | Naze
# Processing Record 12 of Set 8 | Burnie
# Processing Record 13 of Set 8 | Rocha
# Processing Record 14 of Set 8 | Nouakchott
# Processing Record 15 of Set 8 | Oum Hadjer
# Processing Record 16 of Set 8 | Eldorado
# City not found....skipping
# City not found....skipping
# Processing Record 17 of Set 8 | Ebeltoft
# Processing Record 18 of Set 8 | Fukue
# City not found....skipping
# Processing Record 19 of Set 8 | Midlothian
# Processing Record 20 of Set 8 | Tipitapa
# Processing Record 21 of Set 8 | Zonguldak
# Processing Record 22 of Set 8 | Karratha
# Processing Record 23 of Set 8 | Rassvet
# Processing Record 24 of Set 8 | Vao
# Processing Record 25 of Set 8 | Hami
# Processing Record 26 of Set 8 | Vallenar
# Processing Record 27 of Set 8 | Filadelfia
# Processing Record 28 of Set 8 | Los Llanos de Aridane
# Processing Record 29 of Set 8 | Eureka
# Processing Record 30 of Set 8 | Portsmouth
# Processing Record 31 of Set 8 | Tailai
# Processing Record 32 of Set 8 | Vesele
# Processing Record 33 of Set 8 | Voskresenskoye
# Processing Record 34 of Set 8 | Kambove
# Processing Record 35 of Set 8 | Rio Gallegos
# Processing Record 36 of Set 8 | Aswan
# Processing Record 37 of Set 8 | Avera
# Processing Record 38 of Set 8 | Kastamonu
# Processing Record 39 of Set 8 | Dzerzhinsk
# Processing Record 40 of Set 8 | Tondon
# Processing Record 41 of Set 8 | Iqaluit
# Processing Record 42 of Set 8 | Luangwa
# Processing Record 43 of Set 8 | Moyale
# Processing Record 44 of Set 8 | Mehamn
# Processing Record 45 of Set 8 | Sulya
# Processing Record 46 of Set 8 | Cairns
# Processing Record 47 of Set 8 | Verkhnyaya Inta
# Processing Record 48 of Set 8 | Tsiroanomandidy
# Processing Record 49 of Set 8 | Ranong
# Processing Record 50 of Set 8 | Meulaboh
# Processing Record 1 of Set 9 | Hay River
# Processing Record 2 of Set 9 | Zhigansk
# Processing Record 3 of Set 9 | Chahuites
# Processing Record 4 of Set 9 | Padilla
# Processing Record 5 of Set 9 | Coihaique
# Processing Record 6 of Set 9 | Pangody
# Processing Record 7 of Set 9 | Atambua
# Processing Record 8 of Set 9 | Sola
# Processing Record 9 of Set 9 | Camargo
# City not found....skipping
# Processing Record 10 of Set 9 | Matata
# Processing Record 11 of Set 9 | Qena
# Processing Record 12 of Set 9 | Thinadhoo
# Processing Record 13 of Set 9 | Shah Alam
# Processing Record 14 of Set 9 | Shepetivka
# Processing Record 15 of Set 9 | Pakxan
# City not found....skipping
# City not found....skipping
# Processing Record 16 of Set 9 | Qostanay
# Processing Record 17 of Set 9 | Barra Patuca
# Processing Record 18 of Set 9 | Port-Cartier
# Processing Record 19 of Set 9 | Riposto
# Processing Record 20 of Set 9 | Dandong
# Processing Record 21 of Set 9 | Nioro
# Processing Record 22 of Set 9 | Black Diamond
# Processing Record 23 of Set 9 | Nuuk
# Processing Record 24 of Set 9 | Astana
# Processing Record 25 of Set 9 | Adre
# Processing Record 26 of Set 9 | Ouargaye
# City not found....skipping
# Processing Record 27 of Set 9 | Sarishabari
# Processing Record 28 of Set 9 | Westport
# Processing Record 29 of Set 9 | Leningradskiy
# Processing Record 30 of Set 9 | Joensuu
# City not found....skipping
# Processing Record 31 of Set 9 | Kalabo
# Processing Record 32 of Set 9 | Makakilo City
# Processing Record 33 of Set 9 | Lyubokhna
# Processing Record 34 of Set 9 | Tual
# Processing Record 35 of Set 9 | Tawang
# Processing Record 36 of Set 9 | Chimore
# Processing Record 37 of Set 9 | Sapa
# Processing Record 38 of Set 9 | Kysyl-Syr
# Processing Record 39 of Set 9 | Ornskoldsvik
# Processing Record 40 of Set 9 | Altay
# Processing Record 41 of Set 9 | Karasjok
# Processing Record 42 of Set 9 | Waipawa
# Processing Record 43 of Set 9 | Blagoveshchenka
# Processing Record 44 of Set 9 | San Rafael
# Processing Record 45 of Set 9 | Donegal
# Processing Record 46 of Set 9 | Santa Maria
# Processing Record 47 of Set 9 | Gura Humorului
# City not found....skipping
# Processing Record 48 of Set 9 | Lapi
# Processing Record 49 of Set 9 | Kavaratti
# Processing Record 50 of Set 9 | Dalby
# Processing Record 1 of Set 10 | Luocheng
# Processing Record 2 of Set 10 | Ocampo
# City not found....skipping
# Processing Record 3 of Set 10 | Bagdarin
# Processing Record 4 of Set 10 | Kupang
# Processing Record 5 of Set 10 | Somerville
# City not found....skipping
# Processing Record 6 of Set 10 | Bijar
# Processing Record 7 of Set 10 | Maumelle
# Processing Record 8 of Set 10 | Atar
# Processing Record 9 of Set 10 | Sao Joao da Barra
# Processing Record 10 of Set 10 | Libreville
# Processing Record 11 of Set 10 | Mayumba
# Processing Record 12 of Set 10 | Araouane
# Processing Record 13 of Set 10 | Diapaga
# Processing Record 14 of Set 10 | Namatanai
# Processing Record 15 of Set 10 | Moose Factory
# Processing Record 16 of Set 10 | Namibe
# Processing Record 17 of Set 10 | Takoradi
# Processing Record 18 of Set 10 | Vynohradivka
# Processing Record 19 of Set 10 | Pula
# Processing Record 20 of Set 10 | Biltine
# Processing Record 21 of Set 10 | Seoul
# Processing Record 22 of Set 10 | Katangli
# Processing Record 23 of Set 10 | Kilrush
# City not found....skipping
# Processing Record 24 of Set 10 | Tarrafal
# Processing Record 25 of Set 10 | Smolenka
# Processing Record 26 of Set 10 | Apartado
# Processing Record 27 of Set 10 | Aksarka
# Processing Record 28 of Set 10 | Lerwick
# City not found....skipping
# Processing Record 29 of Set 10 | Ayan
# Processing Record 30 of Set 10 | Alta Floresta
# Processing Record 31 of Set 10 | Semirom
# City not found....skipping
# Processing Record 32 of Set 10 | Verkhoyansk
# City not found....skipping
# City not found....skipping
# Processing Record 33 of Set 10 | Vanimo
# Processing Record 34 of Set 10 | Ulaangom
# City not found....skipping
# Processing Record 35 of Set 10 | Majene
# City not found....skipping
# City not found....skipping
# Processing Record 36 of Set 10 | Moche
# Processing Record 37 of Set 10 | Lavrentiya
# Processing Record 38 of Set 10 | Gat
# Processing Record 39 of Set 10 | Erenhot
# Processing Record 40 of Set 10 | Souillac
# Processing Record 41 of Set 10 | Acajutla
# Processing Record 42 of Set 10 | Lenart
# Processing Record 43 of Set 10 | Pacific Grove
# Processing Record 44 of Set 10 | Dicabisagan
# Processing Record 45 of Set 10 | Tabas
# Processing Record 46 of Set 10 | Chifeng
# City not found....skipping
# Processing Record 47 of Set 10 | Skibbereen
# Processing Record 48 of Set 10 | Ola
# Processing Record 49 of Set 10 | Beira
# Processing Record 50 of Set 10 | Cocobeach
# Processing Record 1 of Set 11 | Labuhan
# Processing Record 2 of Set 11 | Dauphin
# Processing Record 3 of Set 11 | Saint Anthony
# Processing Record 4 of Set 11 | Strijen
# Processing Record 5 of Set 11 | San Andres
# Processing Record 6 of Set 11 | Goundam
# Processing Record 7 of Set 11 | Biak
# City not found....skipping
# Processing Record 8 of Set 11 | Ostersund
# Processing Record 9 of Set 11 | Anadyr
# Processing Record 10 of Set 11 | Saint-Louis
# Processing Record 11 of Set 11 | Camapua
# Processing Record 12 of Set 11 | Tongliao
# Processing Record 13 of Set 11 | Kodinar
# Processing Record 14 of Set 11 | Bytow
# Processing Record 15 of Set 11 | Tiruchchendur
# Processing Record 16 of Set 11 | Port Said
# Processing Record 17 of Set 11 | Merauke
# Processing Record 18 of Set 11 | Grand-Lahou
# Processing Record 19 of Set 11 | Rabaul
# Processing Record 20 of Set 11 | Mobaye
# Processing Record 21 of Set 11 | Faya
# Processing Record 22 of Set 11 | Lata
# Processing Record 23 of Set 11 | Troitskoye
# Processing Record 24 of Set 11 | Abay
# Processing Record 25 of Set 11 | Virginia Beach
# Processing Record 26 of Set 11 | Palana
# Processing Record 27 of Set 11 | Cap Malheureux
# Processing Record 28 of Set 11 | Piacabucu
# Processing Record 29 of Set 11 | The Valley
# Processing Record 30 of Set 11 | Gorontalo
# Processing Record 31 of Set 11 | Cockburn Town
# Processing Record 32 of Set 11 | Ust-Nera
# City not found....skipping
# Processing Record 33 of Set 11 | Yar-Sale
# Processing Record 34 of Set 11 | Port Lincoln
# Processing Record 35 of Set 11 | Panaba
# --------------------
# Data Retrieval Complete
# --------------------

# %%
#dataframe for weather data for each city

#empty list for date objects
date_objects=[]

#for loop to format dates from UNIX time
for date in dates:
    formatted_date=datetime.utcfromtimestamp(date).strftime('%Y-%m-%d')
    date_objects.append(formatted_date)
    
#create city weather database
city_weather_raw_df = pd.DataFrame({"City":w_cities,
                                "Cloudiness":cloudiness,
                                "Country":w_countries,
                                "Date":date_objects,
                                "Humidity":humidity,
                                "Lat":weather_lat,
                                "Lon":weather_lon,
                                "Max_Temp":max_temp,
                                "Wind Speed":wind_speed
})

#drop entries where Humidity is reported as >100% and put into new dataframe
city_weather_df = city_weather_raw_df.drop(city_weather_raw_df[city_weather_raw_df.Humidity > 100].index)

#output csv file
city_weather_df.to_csv("output.csv")

#show data frame
city_weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0         Saurimo         100      AO  2019-01-08        96  -9.66   20.40
# 1          Beihai           0      CN  2019-01-08        56  38.95  121.19
# 2           Vaini           0      IN  2019-01-08        82  15.34   74.49
# 3  Saint-Augustin          75      FR  2019-01-08       100  44.83   -0.61
# 4     Honningsvag           0      NO  2019-01-08       100  70.98   25.97
#
#    Max_Temp  Wind Speed
# 0     65.52        2.53
# 1     14.00        2.24
# 2     56.47        3.09
# 3     48.20       12.75
# 4     26.01        6.04

# %%
#Latitude vs. Temperature Plot

plt.scatter(city_weather_df["Lat"], city_weather_df["Max_Temp"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#take first entry in date list for title of chart
title_date = city_weather_df["Date"].iloc[0]

plt.title(F"City Latitude vs. Max Temperature ({title_date})")
plt.savefig("Latitude_vs_Temp.png")
plt.show()

# %%
#Latitude vs. Humidity

plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Humidity ({title_date})")
plt.savefig("Latitude_vs_Humidity.png")
plt.show()

# %%
#Latitude vs. Cloudiness

plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Cloudiness ({title_date})")
plt.savefig("Latitude_vs_Cloudiness.png")
plt.show()

# %%
#Latitude vs. Windspeed

plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], marker="o", facecolors="mediumblue", edgecolors="black", alpha=1)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
title_date = city_weather_df["Date"].iloc[0]
plt.title(F"City Latitude vs. Wind Speed ({title_date})")
plt.savefig("Latitude_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# # Observable trends:
#
# 1.)  summer in the southern hemisphere!  Latitudes below zero are warmer than their comparable latitudes north of the equator.
# 2.)  cloud cover reporting seems inexact?  mostly in intervals of 25%
# 3.)  greater probability of higher wind speeds as one moves away from the equator.
